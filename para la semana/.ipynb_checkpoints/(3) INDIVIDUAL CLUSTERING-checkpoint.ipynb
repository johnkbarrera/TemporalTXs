# %% [markdown]
# # INDIVIDUAL CLUSTERING

# %%
import numpy as np
import datetime
import json
import pylab
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Detalles

# %% [raw]
# Para cada cliente que tiene  S'=< U(1),U(2),...,U(m)>  con m<=n
#
# Entrada      Entrada S'
#              Salida F = {f1,f2,...,fo}    con o<=m
#
#     Procesamos los footprints (U)
#         para i de 1 a u-longitud
#             Usando "MiniBatchKMeans" obtenemos la inercia
#                     k = [1,2,3,...,u-longitud]
#               inercia = [?,?,?,...,?]
#         salida: s1:{k,inercia}
#
#     Mejor k
#         Generamos 1000 puntos con el comportamiento de s1 con la funcion "UnivariateSpline"
#         donde tenemos k',inercia'
#
#          salida: s_final = Cambiar_punto(k',inercia')
#
#     Cambiar_punto(k',inercia')

# %% [markdown]
# ### Lista de Clientes

# %%
# Extraemos la lista de clientes sin repetir

def leer_data():
    outfile='./data2/consulta.csv'
    data = pd.read_csv(outfile)
    return data

data = leer_data()
clientes =  data.groupby('client_id').client_id.count().index

# %% [markdown]
# ## Temporal TXs footprint

# %%
# Definimos la ruta de los archivos 

file='U'
raw_data='./data2/%s.json' %(file)
individual_footprint="%s.individual_footprint" %(raw_data)
individual_clusters="%s.clusters" %(individual_footprint)
individual_labels="%s.labels" %(individual_footprint)

# %% [markdown]
# ### Funciones

# %%
def process_footprint(data,tests,log=False):
    from sklearn.cluster import MiniBatchKMeans
    #KMeans(init='k-means++', n_clusters=k, n_init=10)
    import datetime
    K={}
    for k in tests:
        if k<=len(data):
            if log:
                print("%s: processing %s"%(datetime.datetime.now(),k))
            K[k]=bench_k_means(MiniBatchKMeans(init='k-means++', n_clusters=k, batch_size=100,
                      n_init=10, max_no_improvement=10, verbose=0,
                      random_state=0),name="k-means++", data=data)
    return K

# %%
def compute_best_k(x,y,occurrencies, plot=False,points=1000,sf=0.9):
    import numpy as np
    
    if len(x)<5:
        return max(1, round(np.sqrt(occurrencies/2)))
    
    from scipy.interpolate import interp1d
    from scipy.interpolate import UnivariateSpline
    spl = UnivariateSpline(x, y)
    spl.set_smoothing_factor(sf)
    xs = np.linspace(min(x), max(x), points)
    ys = spl(xs)
    idx_better_k=get_change_point(xs, ys)
    if plot:
        import pylab
        pylab.plot(xs,ys)
        
        pylab.scatter(xs[idx_better_k],ys[idx_better_k],s=20, marker='o')
        pylab.text(xs[idx_better_k],ys[idx_better_k],"bestK %s" %(np.round(xs[idx_better_k])))
        return int(np.round(xs[idx_better_k])),pylab
    return int(np.round(xs[idx_better_k]))

# %%
def bench_k_means(estimator, name, data,distance_function=None):
    from sklearn import metrics
    from sklearn.metrics import silhouette_samples, silhouette_score
    import time
    t0 = time.time()
    if distance_function:
        estimator.fit(data,distance_function)
    else:
        estimator.fit(data)
    #cluster_labels = estimator.fit_predict(data)
    #silhouette_score_ = silhouette_score(data, cluster_labels)
    
    inertia=estimator.inertia_
    duration=time.time() - t0
    return {'inertia':inertia,'duration':duration, 'estimator':estimator}#,'silhouette':silhouette_score_}

def get_change_point(x, y):
    """
         Elección del mejor K
         :: param x: lista de valores de K
         :: param y: lista de valores de SSE
    """
    import math
    max_d = -float('infinity')
    index = 0

    for i in range(0, len(x)):
        c = closest_point_on_segment(a=[x[0], y[0]], b=[x[len(x)-1], y[len(y)-1]], p=[x[i], y[i]])
        d = math.sqrt((c[0]-x[i])**2 + (c[1]-y[i])**2)
        if d > max_d:
            max_d = d
            index = i
    
    return index

def closest_point_on_segment(a, b, p):
    sx1 = a[0]
    sx2 = b[0]
    sy1 = a[1]
    sy2 = b[1]
    px = p[0]
    py = p[1]

    x_delta = sx2 - sx1
    y_delta = sy2 - sy1

    if x_delta == 0 and y_delta == 0:
        return p

    u = ((px - sx1) * x_delta + (py - sy1) * y_delta) / (x_delta * x_delta + y_delta *  y_delta)
    if u < 0:
        closest_point = a
    elif u > 1:
        closest_point = b
    else:
        cp_x = sx1 + u * x_delta
        cp_y = sy1 + u * y_delta
        closest_point = [cp_x, cp_y]

    return closest_point

# %% [markdown]
# ### Individual Clustering

# %% [raw]
# Debe hacerce para cada cliente

# %%
# Numero de filas del archivo
f=open(individual_footprint)
num_rows = len(f.readlines())-1
f.close()

#<customer_id;year;week;profile_id;size;t1... tn >
import datetime
f=open(individual_footprint)
fw=open(individual_clusters,'w')  #uid,cluster_id,centroid
fw2=open(individual_labels,'w') #uid,year,week,cluster_id,profile
fw.write('customer_tag;individual_cluster;d0t0,d1t0,d2t0,d3t0,d4t0,d5t0,d6t0,d0t1,d1t1,d2t1,d3t1,d4t1,d5t1,d6t1,d0t2,d1t2,d2t2,d3t2,d4t2,d5t2,d6t2,d0t3,d1t3,d2t3,d3t3,d4t3,d5t3,d6t3\n')
fw2.write('customer_tag;year;week;individual_cluster;d0t0,d1t0,d2t0,d3t0,d4t0,d5t0,d6t0,d0t1,d1t1,d2t1,d3t1,d4t1,d5t1,d6t1,d0t2,d1t2,d2t2,d3t2,d4t2,d5t2,d6t2,d0t3,d1t3,d2t3,d3t3,d4t3,d5t3,d6t3\n')

f.readline()
data=[] #buffer

footprints_clustered=0
footprints_clusters=0
n_cliente=0
contador = 0
temporal= 0
for row in f: #reading individual footprint
    row=row.strip().split(',') # leemos cada elemento da linea parseada por ","
    uid=row[0]
    year=row[1]
    week=row[2]
    size=int(row[4])
    profile=np.array([float(el) for el in row[5:]])
    # Individual clustering
    if uid==clientes[n_cliente]: # Para cada fila donde los "uid" son iguales 
        data.append(((uid,year,week),profile))     
        contador+=1
    else: #final de cliente
        
        #---------------------------------------------------------------------
        # procesar data
        #---------------------------------------------------------------------
        to_cluster=[el[1] for el in data]
        K=process_footprint(to_cluster,np.arange(1,len(to_cluster)+1))

        # choose k
        x=list(K.keys())
        y=[K[k]['inertia'] for k in K]
        best_k=compute_best_k(x,y,len(to_cluster))
        print(str(contador)+' => clustering: '+str(clientes[n_cliente])+' len data: '+str(len(data))+" best k: "+str(best_k))
        
        # clustering
        if best_k==1:
            #to few records
            cluster_centers_=[np.average(to_cluster,axis=0)]
            labels_=[0]*len(to_cluster)  
        else:
            cluster_centers_=K[best_k]['estimator'].cluster_centers_
            labels_=K[best_k]['estimator'].labels_
        
        #export individual centroids
        for i in np.arange(len(cluster_centers_)):
            string="%s;%s;%s\n"%(clientes[n_cliente],i,';'.join([str(el) for el in cluster_centers_[i]])) #uid,cluster_id,centroid
            fw.write(string)
            footprints_clusters+=1
        fw.flush()

        #export original data and labels
        for i in np.arange(len(data)):
            uid2=data[i][0]
            profile2=data[i][1]
            label2=labels_[i]
            string="%s;%s;%s;%s;%s\n" %(uid2[0],uid2[1],uid2[2],label2
                                                    ,';'.join([str(el) for el in profile2]))#uid,year,week,cluster_id,profile
            fw2.write(string)
            footprints_clustered+=1
        fw2.flush()
        #---------------------------------------------------------------------
        #---------------------------------------------------------------------
        
        

        data=[] #buffer
        data.append(((uid,year,week),profile))
        
        contador+=1
        temporal+=1
        n_cliente+=1
        
    if contador == num_rows:        # Para el ultimo cliente y ultima fila
        #---------------------------------------------------------------------
        # procesar data
        #---------------------------------------------------------------------
        to_cluster=[el[1] for el in data]
        K=process_footprint(to_cluster,np.arange(1,len(to_cluster)+1))

        # choose k
        x=list(K.keys())
        y=[K[k]['inertia'] for k in K]
        best_k=compute_best_k(x,y,len(to_cluster))
        print(str(contador)+' => clustering: '+str(clientes[n_cliente])+' len data: '+str(len(data))+" best k: "+str(best_k))
        
        # clustering
        if best_k==1:
            #to few records
            cluster_centers_=[np.average(to_cluster,axis=0)]
            labels_=[0]*len(to_cluster)  
        else:
            cluster_centers_=K[best_k]['estimator'].cluster_centers_
            labels_=K[best_k]['estimator'].labels_
        
        #export individual centroids
        for i in np.arange(len(cluster_centers_)):
            string="%s;%s;%s\n"%(uid,i,';'.join([str(el) for el in cluster_centers_[i]])) #uid,cluster_id,centroid
            fw.write(string)
            footprints_clusters+=1
        fw.flush()

        #export original data and labels
        for i in np.arange(len(data)):
            uid2=data[i][0]
            profile2=data[i][1]
            label2=labels_[i]
            string="%s;%s;%s;%s;%s\n" %(uid2[0],uid2[1],uid2[2],label2
                                                    ,';'.join([str(el) for el in profile2]))#uid,year,week,cluster_id,profile
            fw2.write(string)
            footprints_clustered+=1
        fw2.flush()
        #---------------------------------------------------------------------
        #---------------------------------------------------------------------
        
        print("final")   
    
    

temporal
# Out:
# 15 => clustering: +++g8j9k+5A= len data: 15 best k: 7
# 44 => clustering: ++/9crwdWSc= len data: 29 best k: 5
# 82 => clustering: ++/NRCUAMIA= len data: 38 best k: 4
# 83 => clustering: ++/bAm/9MuA= len data: 1 best k: 1
# 110 => clustering: ++/nqADqHkE= len data: 27 best k: 9
# 114 => clustering: ++/oQ9Lb9dI= len data: 4 best k: 1
# 118 => clustering: ++0i87zUaWQ= len data: 4 best k: 1
# 153 => clustering: ++0xinBYSBE= len data: 35 best k: 8
# 157 => clustering: ++14g8obpj0= len data: 4 best k: 1
# 159 => clustering: ++1QchhSBuo= len data: 2 best k: 1
# 200 => clustering: ++1XMtcwMec= len data: 41 best k: 9
# 203 => clustering: ++27tu/7+9g= len data: 3 best k: 1
# 204 => clustering: ++2AgIYFkQ8= len data: 1 best k: 1
# 211 => clustering: ++2IlnOb058= len data: 7 best k: 3
# 219 => clustering: ++2bJYMARJk= len data: 8 best k: 5
# 222 => clustering: ++2fs4nrZPo= len data: 3 best k: 1
# 223 => clustering: ++2rVK+/tXs= len data: 1 best k: 1
# 225 => clustering: ++3AMD1kLjA= len data: 2 best k: 1
# 265 => clustering: ++3P3e1vKNQ= len data: 40 best k: 4
# 277 => clustering: ++3SuK4hBMY= len data: 12 best k: 7
# 278 => clustering: ++3gxZFOJCM= len data: 1 best k: 1
# 279 => clustering: ++438ugzEhg= len data: 1 best k: 1
# 281 => clustering: ++5/eQxPUoc= len data: 2 best k: 1
# 310 => clustering: ++5LMVSDY6w= len data: 29 best k: 5
# 312 => clustering: ++5NB27ahhc= len data: 2 best k: 1
# 318 => clustering: ++5h+ru4dNg= len data: 6 best k: 4
# 340 => clustering: ++5u+heOZ8o= len data: 22 best k: 4
# 342 => clustering: ++68m//aQ9E= len data: 2 best k: 1
# 387 => clustering: ++70ByX0a3Q= len data: 45 best k: 10
# 388 => clustering: ++7UqewXdck= len data: 1 best k: 1
# 389 => clustering: ++7Ze6QNPRo= len data: 1 best k: 1
# 428 => clustering: ++7i5fi6kBU= len data: 39 best k: 10
# 436 => clustering: ++8+d9W9Hwo= len data: 8 best k: 4
# 439 => clustering: ++834mPfd7g= len data: 3 best k: 1
# 452 => clustering: ++89+XaWcVw= len data: 13 best k: 3
# 475 => clustering: ++8H96p+hLk= len data: 23 best k: 4
# 507 => clustering: ++8Nf0S2ZTI= len data: 32 best k: 6
# 534 => clustering: ++8ggaxNSYE= len data: 27 best k: 9
# 535 => clustering: ++8p5W4mzvs= len data: 1 best k: 1
# 570 => clustering: ++93ZWJ5ONQ= len data: 35 best k: 4
# 572 => clustering: ++9LcTDzOpQ= len data: 2 best k: 1
# 588 => clustering: ++9NdMvXytk= len data: 16 best k: 5
# 591 => clustering: ++9fviAllzc= len data: 3 best k: 1
# 599 => clustering: ++9tB+M5oWk= len data: 8 best k: 3
# 601 => clustering: ++A6s0Kesy0= len data: 2 best k: 1
# 603 => clustering: ++AAx4tWJqk= len data: 2 best k: 1
# 604 => clustering: ++AJ/PSYwds= len data: 1 best k: 1
# 652 => clustering: ++Amh2kX+w4= len data: 48 best k: 10
# 658 => clustering: ++BIQHDBL6o= len data: 6 best k: 3
# 659 => clustering: ++Bs3PjNldI= len data: 1 best k: 1
# 667 => clustering: ++C7LMgHhcw= len data: 8 best k: 2
# 693 => clustering: ++C82ejGzcQ= len data: 26 best k: 8
# 702 => clustering: ++C9HYE9YAk= len data: 9 best k: 2
# 704 => clustering: ++D4vT77KPI= len data: 2 best k: 1
# 722 => clustering: ++DsXXJe2J0= len data: 18 best k: 6
# 723 => clustering: ++DvoAbU31Q= len data: 1 best k: 1
# 724 => clustering: ++E5lHEE9NY= len data: 1 best k: 1
# 726 => clustering: ++EE525d2hs= len data: 2 best k: 1
# 743 => clustering: ++EXluA5c00= len data: 17 best k: 6
# 746 => clustering: ++EYuDXswJY= len data: 3 best k: 1
# 752 => clustering: ++EbRp2UPOY= len data: 6 best k: 2
# 761 => clustering: ++EsCwOnCME= len data: 9 best k: 5
# 769 => clustering: ++F3gss06ZQ= len data: 8 best k: 3
# 770 => clustering: ++F3n5BLOZg= len data: 1 best k: 1
# 819 => clustering: ++FIcWI9tw4= len data: 49 best k: 12
# 832 => clustering: ++FMZ01PEY4= len data: 13 best k: 4
# 850 => clustering: ++FVgfEREuc= len data: 18 best k: 8
# 851 => clustering: ++G7kZDsa7s= len data: 1 best k: 1
# 853 => clustering: ++GIaJknXNw= len data: 2 best k: 1
# 861 => clustering: ++GvhOxhPGI= len data: 8 best k: 3
# 868 => clustering: ++HCQA6q4v0= len data: 7 best k: 3
# 894 => clustering: ++HEyCkE8U4= len data: 26 best k: 10
# 946 => clustering: ++HNv2JdLoQ= len data: 52 best k: 9
# 947 => clustering: ++HTJkwiu+s= len data: 1 best k: 1
# 949 => clustering: ++HendQWM6s= len data: 2 best k: 1
# 950 => clustering: ++HmIg6AEmI= len data: 1 best k: 1
# 951 => clustering: ++Ho5Lg7tOY= len data: 1 best k: 1
# 952 => clustering: ++HxrcMrbys= len data: 1 best k: 1
# 1001 => clustering: ++I01UG8pgQ= len data: 49 best k: 6
# 1011 => clustering: ++IFcL6GvPs= len data: 10 best k: 5
# 1012 => clustering: ++Ia9NiXU24= len data: 1 best k: 1
# 1055 => clustering: ++JHadWy+ns= len data: 43 best k: 14
# 1067 => clustering: ++JdS34Mwws= len data: 12 best k: 4
# 1068 => clustering: ++JxWznHvfc= len data: 1 best k: 1
# 1110 => clustering: ++JxvYkG8YE= len data: 42 best k: 8
# 1117 => clustering: ++KME7324Iw= len data: 7 best k: 2
# 1162 => clustering: ++KZ8A+f7MY= len data: 45 best k: 8
# 1165 => clustering: ++KhfZchXBc= len data: 3 best k: 1
# 1218 => clustering: ++L0mFgCABw= len data: 53 best k: 7
# 1248 => clustering: ++L6AKuw+Ro= len data: 30 best k: 9
# 1258 => clustering: ++L8PWi+N7s= len data: 10 best k: 6
# 1261 => clustering: ++L9s2riZUE= len data: 3 best k: 1
# 1291 => clustering: ++LFs/38l+M= len data: 30 best k: 8
# 1302 => clustering: ++LHIQljgGU= len data: 11 best k: 3
# 1306 => clustering: ++LWTPW3h1w= len data: 4 best k: 1
# 1307 => clustering: ++LZfzSPdbI= len data: 1 best k: 1
# 1309 => clustering: ++LtXkOanuo= len data: 2 best k: 1
# 1310 => clustering: ++M+L+Inl5Q= len data: 1 best k: 1
# 1332 => clustering: ++M2pwWzRj0= len data: 22 best k: 7
# 1381 => clustering: ++Mr4ALD95c= len data: 49 best k: 7
# 1408 => clustering: ++MrcwKVjZ0= len data: 27 best k: 10
# 1409 => clustering: ++MvCmGS1Xg= len data: 1 best k: 1
# 1410 => clustering: ++MxNRra+yM= len data: 1 best k: 1
# 1418 => clustering: ++NjorN1iZY= len data: 8 best k: 2
# 1426 => clustering: ++OBBUHr6tk= len data: 8 best k: 3
# 1427 => clustering: ++OZ7LE3cG8= len data: 1 best k: 1
# 1429 => clustering: ++OcoshKNA0= len data: 2 best k: 1
# 1430 => clustering: ++OdJDObIWU= len data: 1 best k: 1
# 1432 => clustering: ++OjHFgAwto= len data: 2 best k: 1
# 1433 => clustering: ++OxHOZoaMk= len data: 1 best k: 1
# 1435 => clustering: ++P39TIJncA= len data: 2 best k: 1
# 1436 => clustering: ++P3Splggc8= len data: 1 best k: 1
# 1437 => clustering: ++PBl/W9Psw= len data: 1 best k: 1
# 1443 => clustering: ++PP6RJ2JOU= len data: 6 best k: 3
# 1444 => clustering: ++PpTGzbahg= len data: 1 best k: 1
# 1484 => clustering: ++PqWm8kBNY= len data: 40 best k: 8
# 1486 => clustering: ++Qw2Aq2vxU= len data: 2 best k: 1
# 1487 => clustering: ++R8GLgt6jo= len data: 1 best k: 1
# 1513 => clustering: ++RSzwlsEAs= len data: 26 best k: 11
# 1514 => clustering: ++RrsiPLxKk= len data: 1 best k: 1
# 1524 => clustering: ++S+MUM5TmU= len data: 10 best k: 5
# 1541 => clustering: ++S/sD6wwMM= len data: 17 best k: 8
# 1543 => clustering: ++S8QV+/8NI= len data: 2 best k: 1
# 1544 => clustering: ++ScsTcp7wE= len data: 1 best k: 1
# 1597 => clustering: ++T363m1xs4= len data: 53 best k: 6
# 1610 => clustering: ++TMF8SR+HA= len data: 13 best k: 3
# 1655 => clustering: ++TRf15NWl4= len data: 45 best k: 7
# 1691 => clustering: ++TZRb1OvVo= len data: 36 best k: 11
# 1700 => clustering: ++Tb6dSJreo= len data: 9 best k: 2
# 1704 => clustering: ++TbSpHzSI8= len data: 4 best k: 1
# 1709 => clustering: ++Tk+rxsdzw= len data: 5 best k: 2
# 1713 => clustering: ++TnEWa4RJs= len data: 4 best k: 1
# 1716 => clustering: ++TtPOus7XQ= len data: 3 best k: 1
# 1718 => clustering: ++USi06Y9qk= len data: 2 best k: 1
# 1723 => clustering: ++UjTCpKx6k= len data: 5 best k: 2
# 1729 => clustering: ++V6g86/Cqc= len data: 6 best k: 4
# 1730 => clustering: ++V7Tu7zdEI= len data: 1 best k: 1
# 1747 => clustering: ++VGlJ8+zNE= len data: 17 best k: 6
# 1753 => clustering: ++VL67+12Bg= len data: 6 best k: 4
# 1755 => clustering: ++VX+k3tOYI= len data: 2 best k: 1
# 1759 => clustering: ++W+bwMtB0M= len data: 4 best k: 1
# 1792 => clustering: ++WDNVcbqkE= len data: 33 best k: 6
# 1803 => clustering: ++XKjuQwXic= len data: 11 best k: 3
# 1810 => clustering: ++XMeyxaxac= len data: 7 best k: 4
# 1844 => clustering: ++XlDbl7lno= len data: 34 best k: 10
# 1852 => clustering: ++XsKel+znM= len data: 8 best k: 3
# 1868 => clustering: ++Y2WxO8j/o= len data: 16 best k: 4
# 1872 => clustering: ++YYEyOA0HU= len data: 4 best k: 1
# 1888 => clustering: ++Yg9SnovE4= len data: 16 best k: 3
# 1892 => clustering: ++YxWitfLeM= len data: 4 best k: 1
# 1896 => clustering: ++Z0cEzcGyY= len data: 4 best k: 1
# 1899 => clustering: ++ZXdftEe10= len data: 3 best k: 1
# 1929 => clustering: ++ZZAXWCx9U= len data: 30 best k: 6
# 1938 => clustering: ++aBU5hNvP4= len data: 9 best k: 2
# 1988 => clustering: ++aHRvQdI2E= len data: 50 best k: 14
# 2003 => clustering: ++aPqiCUKXU= len data: 15 best k: 5
# 2027 => clustering: ++aY+RmK3rQ= len data: 24 best k: 10
# 2031 => clustering: ++apsUzdF/A= len data: 4 best k: 1
# 2050 => clustering: ++avHOqcQZg= len data: 19 best k: 2
# 2051 => clustering: ++bCU4cREQQ= len data: 1 best k: 1
# 2055 => clustering: ++bkjQ+iDNs= len data: 4 best k: 1
# 2056 => clustering: ++bsxpSJRP4= len data: 1 best k: 1
# 2064 => clustering: ++clOnxbpk0= len data: 8 best k: 2
# 2089 => clustering: ++cqWmONHM8= len data: 25 best k: 5
# 2102 => clustering: ++cwkQT9HuM= len data: 13 best k: 6
# 2106 => clustering: ++dAyWOTXAk= len data: 4 best k: 1
# 2146 => clustering: ++dXyeMZnRg= len data: 40 best k: 6
# 2152 => clustering: ++dYNgqHClE= len data: 6 best k: 3
# 2154 => clustering: ++dx0F6J4n4= len data: 2 best k: 1
# 2161 => clustering: ++eZlrJULbs= len data: 7 best k: 3
# 2173 => clustering: ++edAkuJwEE= len data: 12 best k: 7
# 2175 => clustering: ++enMtjciho= len data: 2 best k: 1
# 2177 => clustering: ++eqJvfcIik= len data: 2 best k: 1
# 2179 => clustering: ++evDnrVPdI= len data: 2 best k: 1
# 2185 => clustering: ++evgHfd3FQ= len data: 6 best k: 2
# 2189 => clustering: ++f1ON9jXSU= len data: 4 best k: 1
# 2200 => clustering: ++fTixHSPoE= len data: 11 best k: 3
# 2207 => clustering: ++ftaCvivvU= len data: 7 best k: 3
# 2210 => clustering: ++g4xMBILJ0= len data: 3 best k: 1
# 2220 => clustering: ++gGBCDR9iM= len data: 10 best k: 2
# 2241 => clustering: ++gPcM4p3zs= len data: 21 best k: 6
# 2256 => clustering: ++gTwE9p5gc= len data: 15 best k: 5
# 2257 => clustering: ++gcLk9AMf4= len data: 1 best k: 1
# 2273 => clustering: ++glrp9DiJs= len data: 16 best k: 6
# 2275 => clustering: ++h839pKhKE= len data: 2 best k: 1
# 2310 => clustering: ++hAM3VC9oQ= len data: 35 best k: 5
# 2326 => clustering: ++hLlI+jBr8= len data: 16 best k: 6
# 2349 => clustering: ++hM7Yt/Nes= len data: 23 best k: 5
# 2351 => clustering: ++hW5JWeNtw= len data: 2 best k: 1
# 2368 => clustering: ++hbRSRozXo= len data: 17 best k: 7
# 2373 => clustering: ++hsDb5EcBk= len data: 5 best k: 4
# 2378 => clustering: ++i+E0aISJE= len data: 5 best k: 4
# 2384 => clustering: ++iSjezN0KU= len data: 6 best k: 3
# 2391 => clustering: ++ig17OV9fE= len data: 7 best k: 2
# 2396 => clustering: ++isravm2iY= len data: 5 best k: 3
# 2398 => clustering: ++ixiw2fBOw= len data: 2 best k: 1
# 2443 => clustering: ++jQgeK5yQg= len data: 45 best k: 12
# 2446 => clustering: ++jYPQ3XeoA= len data: 3 best k: 1
# 2447 => clustering: ++jq4kt+ufg= len data: 1 best k: 1
# 2450 => clustering: ++kBlx0BUg8= len data: 3 best k: 1
# 2452 => clustering: ++kS/oPhFz0= len data: 2 best k: 1
# 2468 => clustering: ++kV53jEeTk= len data: 16 best k: 6
# 2483 => clustering: ++kbyzE79mk= len data: 15 best k: 10
# 2486 => clustering: ++kdC5AKIBY= len data: 3 best k: 1
# 2515 => clustering: ++kmRi6zLow= len data: 29 best k: 8
# 2517 => clustering: ++krDjTm+oU= len data: 2 best k: 1
# 2524 => clustering: ++l/nlYDGd0= len data: 7 best k: 3
# 2530 => clustering: ++l6ASpxlic= len data: 6 best k: 4
# 2555 => clustering: ++lekFYoUqg= len data: 25 best k: 4
# 2559 => clustering: ++ltGAvW0AM= len data: 4 best k: 1
# 2561 => clustering: ++m294URV60= len data: 2 best k: 1
# 2588 => clustering: ++mAdKXQRVo= len data: 27 best k: 6
# 2589 => clustering: ++mHzYptjww= len data: 1 best k: 1
# 2611 => clustering: ++mQ06zqXfk= len data: 22 best k: 7
# 2630 => clustering: ++mb+jzNKPo= len data: 19 best k: 4
# 2631 => clustering: ++mewDiDrXk= len data: 1 best k: 1
# 2632 => clustering: ++mezWRT9I4= len data: 1 best k: 1
# 2647 => clustering: ++mscMNN5Lo= len data: 15 best k: 7
# 2652 => clustering: ++no4bKZ+P0= len data: 5 best k: 3
# 2655 => clustering: ++nthA8JFBY= len data: 3 best k: 1
# 2672 => clustering: ++o+czw8P44= len data: 17 best k: 3
# 2673 => clustering: ++o9XiNMeH0= len data: 1 best k: 1
# 2692 => clustering: ++oD4f6JmQg= len data: 19 best k: 4
# 2718 => clustering: ++oE5M/Y9gk= len data: 26 best k: 7
# 2723 => clustering: ++oISMACsR0= len data: 5 best k: 3
# 2728 => clustering: ++oMnrMONDI= len data: 5 best k: 4
# 2734 => clustering: ++ou251E4hI= len data: 6 best k: 3
# 2782 => clustering: ++p8Skp1jaM= len data: 48 best k: 6
# 2789 => clustering: ++pBY0QkRSs= len data: 7 best k: 3
# 2790 => clustering: ++pRRFJV6uU= len data: 1 best k: 1
# 2832 => clustering: ++pf4tSHcxU= len data: 42 best k: 5
# 2842 => clustering: ++pkQJSmdcE= len data: 10 best k: 3
# 2846 => clustering: ++poBCeeYFM= len data: 4 best k: 1
# 2883 => clustering: ++prAEPvDk4= len data: 37 best k: 9
# 2892 => clustering: ++q5Y5Vhndw= len data: 9 best k: 4
# 2905 => clustering: ++qKoeokooc= len data: 13 best k: 7
# 2919 => clustering: ++qQNIpeqpA= len data: 14 best k: 2
# 2927 => clustering: ++qa4dSiVrg= len data: 8 best k: 4
# 2931 => clustering: ++rDJdrYjx0= len data: 4 best k: 1
# 2933 => clustering: ++rICSmXjs4= len data: 2 best k: 1
# 2948 => clustering: ++rNbUcexfE= len data: 15 best k: 2
# 2975 => clustering: ++rV6BOvZ8E= len data: 27 best k: 9
# 2980 => clustering: ++rlImPIi64= len data: 5 best k: 4
# 2984 => clustering: ++ro886qY2I= len data: 4 best k: 1
# 2985 => clustering: ++rukSWVn3E= len data: 1 best k: 1
# 2994 => clustering: ++sOah1YItA= len data: 9 best k: 5
# 3001 => clustering: ++stXke4H68= len data: 7 best k: 4
# 3008 => clustering: ++t4ZImnbAc= len data: 7 best k: 3
# 3011 => clustering: ++tI+6BRfJM= len data: 3 best k: 1
# 3026 => clustering: ++tU7cYSuEo= len data: 15 best k: 7
# 3040 => clustering: ++tZQjA+6EY= len data: 14 best k: 4
# 3051 => clustering: ++thDmb2u44= len data: 11 best k: 4
# 3060 => clustering: ++ttZpAAKV0= len data: 9 best k: 4
# 3087 => clustering: ++u2E3fTb7A= len data: 27 best k: 8
# 3100 => clustering: ++u62i5LXJs= len data: 13 best k: 5
# 3102 => clustering: ++uJKNYrKWs= len data: 2 best k: 1
# 3103 => clustering: ++uRlcTb4dA= len data: 1 best k: 1
# 3141 => clustering: ++um8xIKli4= len data: 38 best k: 7
# 3170 => clustering: ++upCtyXFOc= len data: 29 best k: 8
# 3174 => clustering: ++urLUeh4DQ= len data: 4 best k: 1
# 3177 => clustering: ++w/y64u0EA= len data: 3 best k: 1
# 3190 => clustering: ++wb+mTOnu0= len data: 13 best k: 5
# 3191 => clustering: ++wyM6aLJOg= len data: 1 best k: 1
# 3239 => clustering: ++wyZjpH0rY= len data: 48 best k: 5
# 3288 => clustering: ++xDKRJ6IeY= len data: 49 best k: 7
# 3325 => clustering: ++xVlBQE/S8= len data: 37 best k: 15
# 3347 => clustering: ++xd6PFofk4= len data: 22 best k: 5
# 3354 => clustering: ++xrOcEPS8k= len data: 7 best k: 4
# 3365 => clustering: ++y1FCisfIU= len data: 11 best k: 4
# 3369 => clustering: ++y6Ld1PjwU= len data: 4 best k: 1
# 3377 => clustering: ++yc14LXoLM= len data: 8 best k: 2
# 3383 => clustering: ++yfNdEC6Wg= len data: 6 best k: 3
# 3384 => clustering: ++yv14NwWwM= len data: 1 best k: 1
# 3402 => clustering: ++z7vExidEQ= len data: 18 best k: 4
# 3432 => clustering: ++zluHeiaks= len data: 30 best k: 11
# 3436 => clustering: ++zmsxHPO1w= len data: 4 best k: 1
# 3437 => clustering: ++zwCZ1PLK4= len data: 1 best k: 1
# 3440 => clustering: +/+/KcYgEBY= len data: 3 best k: 1
# 3441 => clustering: +/+9W4KyIWg= len data: 1 best k: 1
# 3442 => clustering: +/+AJLKnNOo= len data: 1 best k: 1
# 3452 => clustering: +/+QZhOXKqM= len data: 10 best k: 6
# 3481 => clustering: +/+UT4aIeEc= len data: 29 best k: 8
# 3486 => clustering: +/+uudWZgO0= len data: 5 best k: 3
# 3495 => clustering: +/+viq0t96Q= len data: 9 best k: 4
# 3508 => clustering: +//5qbVGEE4= len data: 13 best k: 5
# 3527 => clustering: +//7/b0IcIY= len data: 19 best k: 7
# 3540 => clustering: +//LEptykcY= len data: 13 best k: 3
# 3541 => clustering: +//NX/cU82Q= len data: 1 best k: 1
# 3553 => clustering: +//NbJMb1OY= len data: 12 best k: 5
# 3602 => clustering: +//SXQ1El20= len data: 49 best k: 10
# 3607 => clustering: +//mw+qc++c= len data: 5 best k: 3
# 3608 => clustering: +//xLEw+o0o= len data: 1 best k: 1
# 3610 => clustering: +/01jP48bkI= len data: 2 best k: 1
# 3619 => clustering: +/0GGaYfzdE= len data: 9 best k: 4
# 3647 => clustering: +/0SroLaRNg= len data: 28 best k: 7
# 3649 => clustering: +/0W1qTC4VA= len data: 2 best k: 1
# 3654 => clustering: +/0lC8BPkgo= len data: 5 best k: 3
# 3656 => clustering: +/199g1Uq70= len data: 2 best k: 1
# 3682 => clustering: +/1DK+68XAw= len data: 26 best k: 7
# 3683 => clustering: +/1IWHi2Om8= len data: 1 best k: 1
# 3731 => clustering: +/1N6bac2+8= len data: 48 best k: 9
# 3777 => clustering: +/1bIPzKF/E= len data: 46 best k: 7
# 3784 => clustering: +/1lGuf8S6Q= len data: 7 best k: 4
# 3785 => clustering: +/1o3XvOZ58= len data: 1 best k: 1
# 3787 => clustering: +/1r3dQnFwk= len data: 2 best k: 1
# 3791 => clustering: +/1wNGlI4L8= len data: 4 best k: 1
# 3795 => clustering: +/1xvnel1fw= len data: 4 best k: 1
# 3799 => clustering: +/3ZCyTGE/A= len data: 4 best k: 1
# 3806 => clustering: +/3aJjVJVnk= len data: 7 best k: 5
# 3808 => clustering: +/3pqgvgCzo= len data: 2 best k: 1
# 3811 => clustering: +/4/FGyY3Ec= len data: 3 best k: 1
# 3812 => clustering: +/47YwGr248= len data: 1 best k: 1
# 3860 => clustering: +/5Eo2IAr/8= len data: 48 best k: 8
# 3863 => clustering: +/5NjtcPsXQ= len data: 3 best k: 1
# 3864 => clustering: +/5d6MEMdyg= len data: 1 best k: 1
# 3865 => clustering: +/6MnR7KK/k= len data: 1 best k: 1
# 3872 => clustering: +/6oMKc5E7g= len data: 7 best k: 3
# 3874 => clustering: +/6pFkRKLOg= len data: 2 best k: 1
# 3879 => clustering: +/71G/9MZ18= len data: 5 best k: 4
# 3885 => clustering: +/7lQeVYAN4= len data: 6 best k: 4
# 3925 => clustering: +/8NouC3pXo= len data: 40 best k: 4
# 3966 => clustering: +/9SzcD/J40= len data: 41 best k: 7
# 3969 => clustering: +/AQAtMBvF0= len data: 3 best k: 1
# 3999 => clustering: +/AXckcHuRU= len data: 30 best k: 9
# 4000 => clustering: +/AtsvJGNiU= len data: 1 best k: 1
# 4002 => clustering: +/B1T7uiChU= len data: 2 best k: 1
# 4055 => clustering: +/B5KZ+ydco= len data: 53 best k: 7
# 4060 => clustering: +/B62xw3nV0= len data: 5 best k: 3
# 4063 => clustering: +/BQN3vsP48= len data: 3 best k: 1
# 4064 => clustering: +/BQsfgIU+Y= len data: 1 best k: 1
# 4069 => clustering: +/BfLPV6nuE= len data: 5 best k: 3
# 4078 => clustering: +/C7dFFlVBY= len data: 9 best k: 6
# 4079 => clustering: +/CD1x4LJgI= len data: 1 best k: 1
# 4083 => clustering: +/CnUHa7AmE= len data: 4 best k: 1
# 4099 => clustering: +/Ct9A9R89Y= len data: 16 best k: 5
# 4102 => clustering: +/D6FnAVPR8= len data: 3 best k: 1
# 4103 => clustering: +/DF7gLbDTE= len data: 1 best k: 1
# 4129 => clustering: +/DPs8iSH50= len data: 26 best k: 10
# 4142 => clustering: +/DbFxc3Nd4= len data: 13 best k: 5
# 4158 => clustering: +/Dec6AZ4fo= len data: 16 best k: 6
# 4203 => clustering: +/Do1tHAglE= len data: 45 best k: 9
# 4206 => clustering: +/Du1y8h6Yo= len data: 3 best k: 1
# 4248 => clustering: +/E/knd/Axs= len data: 42 best k: 11
# 4256 => clustering: +/E9asE5Cjg= len data: 8 best k: 3
# 4260 => clustering: +/EbRHLU4Rs= len data: 4 best k: 1
# 4266 => clustering: +/EcC5r7oCI= len data: 6 best k: 3
# 4267 => clustering: +/EzChJ3Sps= len data: 1 best k: 1
# 4274 => clustering: +/F1elIix+Y= len data: 7 best k: 2
# 4275 => clustering: +/Fu39n2288= len data: 1 best k: 1
# 4276 => clustering: +/G4RbPBlSw= len data: 1 best k: 1
# 4280 => clustering: +/GFLwgcVIk= len data: 4 best k: 1
# 4293 => clustering: +/GuxjhBH+I= len data: 13 best k: 6
# 4299 => clustering: +/H3qxn0LAY= len data: 6 best k: 3
# 4323 => clustering: +/HEk5QGlSc= len data: 24 best k: 5
# 4330 => clustering: +/HExoPbsxo= len data: 7 best k: 3
# 4349 => clustering: +/Hu8vGFxDQ= len data: 19 best k: 5
# 4400 => clustering: +/I9/yAfHHM= len data: 51 best k: 8
# 4404 => clustering: +/IIL5Rkj0E= len data: 4 best k: 1
# 4412 => clustering: +/IdXEaXXP0= len data: 8 best k: 4
# 4417 => clustering: +/ItwSREcaw= len data: 5 best k: 4
# 4420 => clustering: +/JUAndLi2g= len data: 3 best k: 1
# 4432 => clustering: +/JUR+vgwME= len data: 12 best k: 3
# 4455 => clustering: +/JbOVlcFI4= len data: 23 best k: 4
# 4463 => clustering: +/KBpUfLVBs= len data: 8 best k: 4
# 4464 => clustering: +/KCCsfUfFA= len data: 1 best k: 1
# 4467 => clustering: +/Ks3eee1SQ= len data: 3 best k: 1
# 4469 => clustering: +/Kv0KgRPbs= len data: 2 best k: 1
# 4503 => clustering: +/L/p66w1+o= len data: 34 best k: 7
# 4508 => clustering: +/LDZUxmQ7g= len data: 5 best k: 3
# 4519 => clustering: +/LQ7v+zKOs= len data: 11 best k: 3
# 4523 => clustering: +/La+pgtTSg= len data: 4 best k: 1
# 4552 => clustering: +/Lg9gPCTiQ= len data: 29 best k: 5
# 4553 => clustering: +/LrP6kHYE0= len data: 1 best k: 1
# 4559 => clustering: +/MI0itNeUg= len data: 6 best k: 3
# 4560 => clustering: +/MW8tqeXFs= len data: 1 best k: 1
# 4562 => clustering: +/MyzvZfMPU= len data: 2 best k: 1
# 4600 => clustering: +/N5ebWxSl8= len data: 38 best k: 10
# 4601 => clustering: +/N7hT1sd8c= len data: 1 best k: 1
# 4610 => clustering: +/NA9A16gU4= len data: 9 best k: 4
# 4611 => clustering: +/ND8N2jJkw= len data: 1 best k: 1
# 4617 => clustering: +/NOIG5Gic8= len data: 6 best k: 3
# 4645 => clustering: +/NOskxSDEQ= len data: 28 best k: 5
# 4680 => clustering: +/NPHE5n8NY= len data: 35 best k: 1
# 4682 => clustering: +/NQduInyuk= len data: 2 best k: 1
# 4694 => clustering: +/NUxapLxIY= len data: 12 best k: 3
# 4696 => clustering: +/Nn7U02NDM= len data: 2 best k: 1
# 4721 => clustering: +/O5cE/S3IE= len data: 25 best k: 6
# 4729 => clustering: +/OJjHYB6SA= len data: 8 best k: 2
# 4734 => clustering: +/OPVQz+TH8= len data: 5 best k: 3
# 4736 => clustering: +/P/IQCTb0o= len data: 2 best k: 1
# 4757 => clustering: +/PPhxkbxxA= len data: 21 best k: 6
# 4758 => clustering: +/PrucPd/HM= len data: 1 best k: 1
# 4759 => clustering: +/QYvQrwQaU= len data: 1 best k: 1
# 4772 => clustering: +/Qh3u1s7CI= len data: 13 best k: 4
# 4773 => clustering: +/QlVsjACew= len data: 1 best k: 1
# 4774 => clustering: +/RYRQ7wSpE= len data: 1 best k: 1
# 4782 => clustering: +/RZUSZzRZE= len data: 8 best k: 4
# 4833 => clustering: +/Rx6WbUFrU= len data: 51 best k: 6
# 4841 => clustering: +/SOp4Kjd0U= len data: 8 best k: 3
# 4870 => clustering: +/SZj7DUUv8= len data: 29 best k: 5
# 4879 => clustering: +/SkXiWvHTs= len data: 9 best k: 3
# 4880 => clustering: +/TwuT+OCXY= len data: 1 best k: 1
# 4896 => clustering: +/U0hKVxDVM= len data: 16 best k: 4
# 4897 => clustering: +/U6jjDciuo= len data: 1 best k: 1
# 4898 => clustering: +/UMOt7cEnc= len data: 1 best k: 1
# 4901 => clustering: +/Uya5XGqTg= len data: 3 best k: 1
# 4915 => clustering: +/V2rjeuDjU= len data: 14 best k: 6
# 4917 => clustering: +/VRsyEvjUg= len data: 2 best k: 1
# 4946 => clustering: +/VSJNxKAyg= len data: 29 best k: 8
# 4953 => clustering: +/Vl/LE+ZF8= len data: 7 best k: 4
# 4954 => clustering: +/WW9L9DpyQ= len data: 1 best k: 1
# 4973 => clustering: +/WYoatWQVM= len data: 19 best k: 5
# 4998 => clustering: +/WtcHZMNW0= len data: 25 best k: 7
# 5020 => clustering: +/XLRBkrjwc= len data: 22 best k: 4
# 5025 => clustering: +/XNTF05dRY= len data: 5 best k: 3
# 5048 => clustering: +/Xg2R/qnNc= len data: 23 best k: 5
# 5058 => clustering: +/Xr9E3TmyY= len data: 10 best k: 3
# 5078 => clustering: +/Y6s61bkA8= len data: 20 best k: 4
# 5085 => clustering: +/YUzQES66M= len data: 7 best k: 4
# 5086 => clustering: +/YfssdLhM8= len data: 1 best k: 1
# 5097 => clustering: +/YnqUV3fLc= len data: 11 best k: 3
# 5101 => clustering: +/Z0x15uBZU= len data: 4 best k: 1
# 5103 => clustering: +/Z43cKsFAA= len data: 2 best k: 1
# 5112 => clustering: +/Z4z/BhJf4= len data: 9 best k: 5
# 5155 => clustering: +/ZKKE7wEHI= len data: 43 best k: 9
# 5158 => clustering: +/ZMript83E= len data: 3 best k: 1
# 5179 => clustering: +/Zg8+3Rq3M= len data: 21 best k: 5
# 5226 => clustering: +/ZjaBaGi5w= len data: 47 best k: 16
# 5228 => clustering: +/aBIU+8PSs= len data: 2 best k: 1
# 5230 => clustering: +/aJKq0V9Ec= len data: 2 best k: 1
# 5231 => clustering: +/aS9eqaUXE= len data: 1 best k: 1
# 5260 => clustering: +/aiX8H8/JE= len data: 29 best k: 8
# 5284 => clustering: +/bC0saIhDQ= len data: 24 best k: 6
# 5306 => clustering: +/bdaZawnDg= len data: 22 best k: 7
# 5313 => clustering: +/bxGlHbIdA= len data: 7 best k: 3
# 5320 => clustering: +/c2/yXup68= len data: 7 best k: 4
# 5328 => clustering: +/c2KikNOQM= len data: 8 best k: 4
# 5333 => clustering: +/cegB09A90= len data: 5 best k: 3
# 5354 => clustering: +/ddXg+ZlFk= len data: 21 best k: 4
# 5379 => clustering: +/dfCsfQ4uY= len data: 25 best k: 1
# 5382 => clustering: +/ducdzNBbg= len data: 3 best k: 1
# 5393 => clustering: +/e3OBdo1pg= len data: 11 best k: 3
# 5396 => clustering: +/eNtytOtf0= len data: 3 best k: 1
# 5401 => clustering: +/efhHtcKkA= len data: 5 best k: 2
# 5411 => clustering: +/egZYBTSN8= len data: 10 best k: 5
# 5413 => clustering: +/ehJQwHFUU= len data: 2 best k: 1
# 5415 => clustering: +/ehaU3lHnQ= len data: 2 best k: 1
# 5417 => clustering: +/f2fqb35JU= len data: 2 best k: 1
# 5420 => clustering: +/f5Tqpo114= len data: 3 best k: 1
# 5435 => clustering: +/f8o9ONOow= len data: 15 best k: 4
# 5439 => clustering: +/fJ/IRbkUA= len data: 4 best k: 1
# 5443 => clustering: +/g9ZV6ROPc= len data: 4 best k: 1
# 5444 => clustering: +/gIj7J6/qY= len data: 1 best k: 1
# 5482 => clustering: +/gXibKHs04= len data: 38 best k: 1
# 5485 => clustering: +/gibTt07O0= len data: 3 best k: 1
# 5531 => clustering: +/gzDLGsDLY= len data: 46 best k: 11
# 5546 => clustering: +/gzkeNhhz4= len data: 15 best k: 5
# 5556 => clustering: +/h6HlctOvc= len data: 10 best k: 5
# 5557 => clustering: +/hPSWKEJYo= len data: 1 best k: 1
# 5580 => clustering: +/hbYzZV/Es= len data: 23 best k: 6
# 5584 => clustering: +/hoWSU9ODk= len data: 4 best k: 1
# 5629 => clustering: +/hxtu5mmSk= len data: 45 best k: 6
# 5669 => clustering: +/i0RR6Srn8= len data: 40 best k: 7
# 5700 => clustering: +/iI+4Xnqb0= len data: 31 best k: 8
# 5702 => clustering: +/iWK36Jm5A= len data: 2 best k: 1
# 5705 => clustering: +/ifHandHpw= len data: 3 best k: 1
# 5729 => clustering: +/irfhG5ElQ= len data: 24 best k: 5
# 5734 => clustering: +/ivfRVaStc= len data: 5 best k: 2
# 5735 => clustering: +/iy1hU7zrg= len data: 1 best k: 1
# 5739 => clustering: +/jGZN143ac= len data: 4 best k: 1
# 5778 => clustering: +/jPdOoEh18= len data: 39 best k: 11
# 5782 => clustering: +/joH6YU7Ug= len data: 4 best k: 1
# 5783 => clustering: +/jrZIxYzWE= len data: 1 best k: 1
# 5786 => clustering: +/jrdPiunjw= len data: 3 best k: 1
# 5803 => clustering: +/jzZjfDbJg= len data: 17 best k: 4
# 5811 => clustering: +/kRJ75FkWs= len data: 8 best k: 4
# 5815 => clustering: +/kTHqX3zOw= len data: 4 best k: 1
# 5843 => clustering: +/kUsxVFY04= len data: 28 best k: 4
# 5866 => clustering: +/kalZl8ZzE= len data: 23 best k: 4
# 5883 => clustering: +/ke6tZ1p/w= len data: 17 best k: 3
# 5889 => clustering: +/l3jzNFdiQ= len data: 6 best k: 2
# 5908 => clustering: +/lD5dlCkgo= len data: 19 best k: 7
# 5925 => clustering: +/lJnP3rdP8= len data: 17 best k: 9
# 5927 => clustering: +/lM6B5CDO0= len data: 2 best k: 1
# 5949 => clustering: +/lOkYHgQps= len data: 22 best k: 5
# 5961 => clustering: +/lp/3zR00I= len data: 12 best k: 7
# 5974 => clustering: +/lwORIljCU= len data: 13 best k: 4
# 5977 => clustering: +/m6i11W2Ao= len data: 3 best k: 1
# 5978 => clustering: +/m8k16AtkY= len data: 1 best k: 1
# 6020 => clustering: +/mijipcEeQ= len data: 42 best k: 9
# 6025 => clustering: +/mmcUnu4qc= len data: 5 best k: 4
# 6026 => clustering: +/moncvrZa0= len data: 1 best k: 1
# 6030 => clustering: +/mxg4k0t7M= len data: 4 best k: 1
# 6042 => clustering: +/n6c46rvPs= len data: 12 best k: 5
# 6072 => clustering: +/noqAuXyM4= len data: 30 best k: 9
# 6106 => clustering: +/nxp0Hx8gw= len data: 34 best k: 5
# 6129 => clustering: +/oJfnANIYw= len data: 23 best k: 7
# 6131 => clustering: +/ok976aBKQ= len data: 2 best k: 1
# 6132 => clustering: +/owqDrGC6A= len data: 1 best k: 1
# 6134 => clustering: +/ozjSFISfQ= len data: 2 best k: 1
# 6135 => clustering: +/p80mQiVSw= len data: 1 best k: 1
# 6147 => clustering: +/pSt2GoSBg= len data: 12 best k: 3
# 6148 => clustering: +/pyyQp5Au0= len data: 1 best k: 1
# 6155 => clustering: +/q+OcbDtn0= len data: 7 best k: 3
# 6159 => clustering: +/qI2hva9gs= len data: 4 best k: 1
# 6165 => clustering: +/ql8Z+G2xo= len data: 6 best k: 3
# 6167 => clustering: +/qtQHDZ1aQ= len data: 2 best k: 1
# 6175 => clustering: +/r0Ndg3Emc= len data: 8 best k: 4
# 6198 => clustering: +/rHyykzsNo= len data: 23 best k: 6
# 6216 => clustering: +/rIez4ludw= len data: 18 best k: 5
# 6218 => clustering: +/rKEw7kWx8= len data: 2 best k: 1
# 6226 => clustering: +/rNIca2oUU= len data: 8 best k: 3
# 6240 => clustering: +/rVD0fENmY= len data: 14 best k: 5
# 6265 => clustering: +/sJFk6Re7Q= len data: 25 best k: 8
# 6274 => clustering: +/sJwHOL8hY= len data: 9 best k: 5
# 6283 => clustering: +/sTt49I/Ww= len data: 9 best k: 2
# 6302 => clustering: +/stB6tc6EA= len data: 19 best k: 4
# 6305 => clustering: +/t1Wy17/aU= len data: 3 best k: 1
# 6331 => clustering: +/t2CEPOiGE= len data: 26 best k: 5
# 6334 => clustering: +/tci+3hKDg= len data: 3 best k: 1
# 6365 => clustering: +/tfB3Ql+34= len data: 31 best k: 6
# 6366 => clustering: +/tg3+EEksU= len data: 1 best k: 1
# 6409 => clustering: +/thXqwpD3k= len data: 43 best k: 4
# 6410 => clustering: +/tw0zq2pUE= len data: 1 best k: 1
# 6419 => clustering: +/uBZ8FJbaM= len data: 9 best k: 5
# 6433 => clustering: +/uo/qrDvYM= len data: 14 best k: 3
# 6434 => clustering: +/uzyK2wDYQ= len data: 1 best k: 1
# 6435 => clustering: +/v73plZrzo= len data: 1 best k: 1
# 6436 => clustering: +/vQxqB0qCM= len data: 1 best k: 1
# 6441 => clustering: +/viRONL8zk= len data: 5 best k: 2
# 6442 => clustering: +/vmDFJm06s= len data: 1 best k: 1
# 6450 => clustering: +/wAksSrFkI= len data: 8 best k: 3
# 6454 => clustering: +/wDnb1y46k= len data: 4 best k: 1
# 6475 => clustering: +/wG2gy5XZA= len data: 21 best k: 5
# 6477 => clustering: +/wZzfB87hA= len data: 2 best k: 1
# 6480 => clustering: +/wbaBiiH/M= len data: 3 best k: 1
# 6484 => clustering: +/wjWhz3hh8= len data: 4 best k: 1
# 6485 => clustering: +/wxL5QtHXc= len data: 1 best k: 1
# 6486 => clustering: +/xVPZs+up8= len data: 1 best k: 1
# 6487 => clustering: +/xs3Npq7gQ= len data: 1 best k: 1
# 6495 => clustering: +/xvpmRJ92I= len data: 8 best k: 3
# 6496 => clustering: +/y4+pEbde8= len data: 1 best k: 1
# 6501 => clustering: +/y7QsXVM/g= len data: 5 best k: 3
# 6516 => clustering: +/y8xHEXLUg= len data: 15 best k: 1
# 6563 => clustering: +/yPWUe76yw= len data: 47 best k: 7
# 6614 => clustering: +/z3oL/3bRU= len data: 51 best k: 9
# 6615 => clustering: +/zu5STBtHY= len data: 1 best k: 1
# 6616 => clustering: +/zyXchFT/E= len data: 1 best k: 1
# 6617 => clustering: +0+0K3XJA/o= len data: 1 best k: 1
# 6619 => clustering: +0+FlPkqniY= len data: 2 best k: 1
# 6626 => clustering: +0+J54Rbzjc= len data: 7 best k: 3
# 6627 => clustering: +0+XEX5+YFI= len data: 1 best k: 1
# 6630 => clustering: +0+XpYsXUPA= len data: 3 best k: 1
# 6647 => clustering: +0+yyLKK4Yw= len data: 17 best k: 7
# 6648 => clustering: +0/0nMsK2lM= len data: 1 best k: 1
# 6653 => clustering: +0/GyKPRZv4= len data: 5 best k: 3
# 6655 => clustering: +0/IfwP/73w= len data: 2 best k: 1
# 6662 => clustering: +0/lkzs2+RU= len data: 7 best k: 4
# 6674 => clustering: +0/tBx7yEE0= len data: 12 best k: 3
# 6728 => clustering: +00+ifm9RAo= len data: 54 best k: 10
# 6729 => clustering: +00Bh0Ouu6o= len data: 1 best k: 1
# 6745 => clustering: +00Bkuu0r/o= len data: 16 best k: 8
# 6774 => clustering: +00FrHM4OW8= len data: 29 best k: 5
# 6787 => clustering: +00OC+mZBxQ= len data: 13 best k: 3
# 6831 => clustering: +00QQRkLAUs= len data: 44 best k: 6
# 6833 => clustering: +00Qx/7BzIU= len data: 2 best k: 1
# 6836 => clustering: +01TvNwaXEA= len data: 3 best k: 1
# 6837 => clustering: +01miLvo634= len data: 1 best k: 1
# 6841 => clustering: +023FiidRe0= len data: 4 best k: 1
# 6851 => clustering: +02bvILli7k= len data: 10 best k: 6
# 6859 => clustering: +02tQW88ALo= len data: 8 best k: 3
# 6863 => clustering: +033+EWY90U= len data: 4 best k: 1
# 6867 => clustering: +03CSmikL4w= len data: 4 best k: 1
# 6869 => clustering: +03SaBuv64A= len data: 2 best k: 1
# 6877 => clustering: +04/9J6AuTk= len data: 8 best k: 4
# 6890 => clustering: +04Cj7LjtT4= len data: 13 best k: 3
# 6894 => clustering: +04MjjLYjEU= len data: 4 best k: 1
# 6896 => clustering: +04uRPaIy3I= len data: 2 best k: 1
# 6899 => clustering: +04wo1II+Os= len data: 3 best k: 1
# 6945 => clustering: +04zbis1ZH4= len data: 46 best k: 10
# 6957 => clustering: +05Fu5e4vRk= len data: 12 best k: 3
# 6973 => clustering: +05QQzuESoA= len data: 16 best k: 6
# 6974 => clustering: +0692HOAtsw= len data: 1 best k: 1
# 6978 => clustering: +06MLIKIuUI= len data: 4 best k: 1
# 6980 => clustering: +06Pa1Ph5Fs= len data: 2 best k: 1
# 7005 => clustering: +07P0nux4Vw= len data: 25 best k: 6
# 7006 => clustering: +07eLUPYVUA= len data: 1 best k: 1
# 7007 => clustering: +08DjsO8y3Y= len data: 1 best k: 1
# 7012 => clustering: +08K+0gjfag= len data: 5 best k: 2
# 7013 => clustering: +08Rvm1G8Vo= len data: 1 best k: 1
# 7023 => clustering: +08YTTbHiZs= len data: 10 best k: 3
# 7033 => clustering: +08ehRxJhmo= len data: 10 best k: 3
# 7036 => clustering: +08h/x5qWls= len data: 3 best k: 1
# 7049 => clustering: +08w2AHd3Dg= len data: 13 best k: 7
# 7053 => clustering: +08yDbDwGLE= len data: 4 best k: 1
# 7054 => clustering: +098x+aY070= len data: 1 best k: 1
# 7062 => clustering: +09Ef8vnzJY= len data: 8 best k: 4
# 7076 => clustering: +09L2820aF8= len data: 14 best k: 6
# 7084 => clustering: +0A8y+Hw8rE= len data: 8 best k: 5
# 7089 => clustering: +0AHVKegd9Q= len data: 5 best k: 2
# 7092 => clustering: +0AathEAnOY= len data: 3 best k: 1
# 7097 => clustering: +0BcaL6KLp8= len data: 5 best k: 3
# 7104 => clustering: +0BoaWlaXZE= len data: 7 best k: 3
# 7106 => clustering: +0CJwVV6VTg= len data: 2 best k: 1
# 7107 => clustering: +0CLTbo8kEQ= len data: 1 best k: 1
# 7108 => clustering: +0CTOl/wIwE= len data: 1 best k: 1
# 7122 => clustering: +0CdF34H9j8= len data: 14 best k: 5
# 7128 => clustering: +0CwZYdJtik= len data: 6 best k: 2
# 7173 => clustering: +0CyBDzgj3c= len data: 45 best k: 8
# 7209 => clustering: +0D87UEt3fs= len data: 36 best k: 6
# 7212 => clustering: +0DB/9wocrc= len data: 3 best k: 1
# 7213 => clustering: +0DEfQja2Pg= len data: 1 best k: 1
# 7214 => clustering: +0DOzp/OCuI= len data: 1 best k: 1
# 7217 => clustering: +0DXTuodmrM= len data: 3 best k: 1
# 7231 => clustering: +0DYz/dowGk= len data: 14 best k: 4
# 7242 => clustering: +0DsIUvnFOA= len data: 11 best k: 7
# 7274 => clustering: +0DzqJe+9CU= len data: 32 best k: 6
# 7288 => clustering: +0E1QMQ6x2o= len data: 14 best k: 3
# 7290 => clustering: +0E4IYz7CXk= len data: 2 best k: 1
# 7308 => clustering: +0EBN4qHn1U= len data: 18 best k: 6
# 7309 => clustering: +0EBVRDclz0= len data: 1 best k: 1
# 7312 => clustering: +0EuSX12eM0= len data: 3 best k: 1
# 7313 => clustering: +0FCZ403ExM= len data: 1 best k: 1
# 7319 => clustering: +0FHTVK5/HU= len data: 6 best k: 4
# 7322 => clustering: +0FRNmhHD9k= len data: 3 best k: 1
# 7325 => clustering: +0Fbkdv+958= len data: 3 best k: 1
# 7347 => clustering: +0G7ucx0X8o= len data: 22 best k: 8
# 7359 => clustering: +0GFUDru32o= len data: 12 best k: 4
# 7368 => clustering: +0GQoMGK2GY= len data: 9 best k: 4
# 7372 => clustering: +0Gbw/9LOtM= len data: 4 best k: 1
# 7397 => clustering: +0Gi3wXIjeM= len data: 25 best k: 13
# 7400 => clustering: +0H4y9zVkzI= len data: 3 best k: 1
# 7401 => clustering: +0HMmryW8Oo= len data: 1 best k: 1
# 7402 => clustering: +0Ha5myDtjs= len data: 1 best k: 1
# 7410 => clustering: +0HosftrSds= len data: 8 best k: 5
# 7455 => clustering: +0HvYsoNmkE= len data: 45 best k: 8
# 7462 => clustering: +0HxM4NATYo= len data: 7 best k: 4
# 7465 => clustering: +0HxPSdr1JI= len data: 3 best k: 1
# 7496 => clustering: +0J5D0t2brA= len data: 31 best k: 6
# 7503 => clustering: +0JIPC1fr0Q= len data: 7 best k: 2
# 7504 => clustering: +0JhU73Lby8= len data: 1 best k: 1
# 7510 => clustering: +0JpS0738NE= len data: 6 best k: 5
# 7540 => clustering: +0KAHUWZxyA= len data: 30 best k: 9
# 7544 => clustering: +0KV8Ru5S3s= len data: 4 best k: 1
# 7574 => clustering: +0Kldqr5Ccw= len data: 30 best k: 7
# 7587 => clustering: +0L7RFrqKbc= len data: 13 best k: 5
# 7589 => clustering: +0LNKu41yqY= len data: 2 best k: 1
# 7634 => clustering: +0LXm9FfEFI= len data: 45 best k: 6
# 7645 => clustering: +0LoL7quFBg= len data: 11 best k: 5
# 7646 => clustering: +0Lx7rXuK1g= len data: 1 best k: 1
# 7648 => clustering: +0M9FRtU1s0= len data: 2 best k: 1
# 7684 => clustering: +0MRXld+jC0= len data: 36 best k: 8
# 7690 => clustering: +0NSGXLy2jM= len data: 6 best k: 4
# 7725 => clustering: +0Nei/L84D8= len data: 35 best k: 8
# 7749 => clustering: +0Nv4IzjGF8= len data: 24 best k: 5
# 7780 => clustering: +0NyQINF1Ws= len data: 31 best k: 9
# 7783 => clustering: +0O/Z9Nm5vU= len data: 3 best k: 1
# 7784 => clustering: +0OTPqvqhiw= len data: 1 best k: 1
# 7791 => clustering: +0Obwc48nME= len data: 7 best k: 4
# 7794 => clustering: +0Oc4PHiMuQ= len data: 3 best k: 1
# 7817 => clustering: +0Oca3ccv8E= len data: 23 best k: 7
# 7856 => clustering: +0Odpb2A540= len data: 39 best k: 11
# 7875 => clustering: +0OfGOCAGMI= len data: 19 best k: 3
# 7876 => clustering: +0P9giH3tSE= len data: 1 best k: 1
# 7915 => clustering: +0Q09bzz70A= len data: 39 best k: 8
# 7922 => clustering: +0QGpF1kdew= len data: 7 best k: 3
# 7924 => clustering: +0QMFfnFLdg= len data: 2 best k: 1
# 7931 => clustering: +0QgD1OB29Q= len data: 7 best k: 3
# 7975 => clustering: +0QrvwBcd3s= len data: 44 best k: 10
# 7978 => clustering: +0RE8/UtLJk= len data: 3 best k: 1
# 7991 => clustering: +0RiZXoS6UU= len data: 13 best k: 3
# 7995 => clustering: +0RrQN0LHt0= len data: 4 best k: 1
# 7997 => clustering: +0SHjdLEBjE= len data: 2 best k: 1
# 8027 => clustering: +0T0ltbIAe8= len data: 30 best k: 8
# 8028 => clustering: +0TNKkO45fs= len data: 1 best k: 1
# 8074 => clustering: +0TgDmDpJvc= len data: 46 best k: 8
# 8076 => clustering: +0UM+ftOOmo= len data: 2 best k: 1
# 8083 => clustering: +0Ult5EOMLw= len data: 7 best k: 3
# 8084 => clustering: +0VFdPbdS9A= len data: 1 best k: 1
# 8085 => clustering: +0VMLX//Xf0= len data: 1 best k: 1
# 8093 => clustering: +0VRbNMixWI= len data: 8 best k: 4
# 8104 => clustering: +0Vo8uhZmFs= len data: 11 best k: 4
# 8111 => clustering: +0VuLUpRWtA= len data: 7 best k: 3
# 8134 => clustering: +0W7PTTwyMg= len data: 23 best k: 9
# 8141 => clustering: +0WE2FqeOTg= len data: 7 best k: 3
# 8157 => clustering: +0WJHBGbDHM= len data: 16 best k: 6
# 8158 => clustering: +0WVks70DtQ= len data: 1 best k: 1
# 8184 => clustering: +0WbRMXihqo= len data: 26 best k: 4
# 8193 => clustering: +0WjOQSeePE= len data: 9 best k: 4
# 8210 => clustering: +0X4wMkqjWI= len data: 17 best k: 5
# 8213 => clustering: +0Xb7j6QJlo= len data: 3 best k: 1
# 8216 => clustering: +0Xw+H2lm4Q= len data: 3 best k: 1
# 8239 => clustering: +0XwCaJSo60= len data: 23 best k: 8
# 8246 => clustering: +0Y4AI1K+pQ= len data: 7 best k: 5
# 8247 => clustering: +0Y4YR4khSw= len data: 1 best k: 1
# 8254 => clustering: +0YGm+emv78= len data: 7 best k: 4
# 8255 => clustering: +0YUqkgGSpE= len data: 1 best k: 1
# 8273 => clustering: +0YZwLGvF2U= len data: 18 best k: 5
# 8284 => clustering: +0YzZpkqsDA= len data: 11 best k: 3
# 8292 => clustering: +0Z+HHVt6nM= len data: 8 best k: 5
# 8299 => clustering: +0Z1HHO7q3g= len data: 7 best k: 2
# 8350 => clustering: +0ZY8A6VphE= len data: 51 best k: 9
# 8352 => clustering: +0ZcHB/uTjw= len data: 2 best k: 1
# 8353 => clustering: +0a61SwdXS8= len data: 1 best k: 1
# 8357 => clustering: +0aB3tRLhaw= len data: 4 best k: 1
# 8358 => clustering: +0aBBxnWJHU= len data: 1 best k: 1
# 8364 => clustering: +0aFjLVbX1A= len data: 6 best k: 4
# 8371 => clustering: +0aMwQk+I1s= len data: 7 best k: 3
# 8394 => clustering: +0b0wRqO8HM= len data: 23 best k: 5
# 8402 => clustering: +0b2piuQjLk= len data: 8 best k: 4
# 8403 => clustering: +0bHXCdwbWk= len data: 1 best k: 1
# 8453 => clustering: +0bSx9HLGBs= len data: 50 best k: 11
# 8493 => clustering: +0baO7+Djns= len data: 40 best k: 7
# 8495 => clustering: +0c3Ltu9LYw= len data: 2 best k: 1
# 8510 => clustering: +0ccIgpbR50= len data: 15 best k: 5
# 8535 => clustering: +0cnPv0s9Ug= len data: 25 best k: 4
# 8536 => clustering: +0d/N+2kMWI= len data: 1 best k: 1
# 8539 => clustering: +0d8YuZWg8s= len data: 3 best k: 1
# 8540 => clustering: +0dJesvV+Do= len data: 1 best k: 1
# 8546 => clustering: +0dMT3snbbs= len data: 6 best k: 3
# 8549 => clustering: +0dg5xYuLOE= len data: 3 best k: 1
# 8552 => clustering: +0e9K1yGcOA= len data: 3 best k: 1
# 8553 => clustering: +0eL6pYRCUU= len data: 1 best k: 1
# 8556 => clustering: +0ebrsfkDqc= len data: 3 best k: 1
# 8573 => clustering: +0eeihBgRCo= len data: 17 best k: 5
# 8576 => clustering: +0eiwl5NhPU= len data: 3 best k: 1
# 8577 => clustering: +0eoVlWAuiw= len data: 1 best k: 1
# 8591 => clustering: +0fUr7JQMM8= len data: 14 best k: 4
# 8601 => clustering: +0foLbSTHYo= len data: 10 best k: 3
# 8606 => clustering: +0gKt/BbxDE= len data: 5 best k: 2
# 8610 => clustering: +0h+BqMZvyk= len data: 4 best k: 1
# 8620 => clustering: +0h6OW1GAjY= len data: 10 best k: 4
# 8671 => clustering: +0heOoWxHeA= len data: 51 best k: 5
# 8679 => clustering: +0i1cwrcnEs= len data: 8 best k: 3
# 8680 => clustering: +0i8FP2nP4Q= len data: 1 best k: 1
# 8688 => clustering: +0iOu79XZHg= len data: 8 best k: 5
# 8689 => clustering: +0ijz9WLY04= len data: 1 best k: 1
# 8690 => clustering: +0imMDZx8WI= len data: 1 best k: 1
# 8697 => clustering: +0j0p/+lKYA= len data: 7 best k: 4
# 8717 => clustering: +0jIBjJPdCE= len data: 20 best k: 7
# 8728 => clustering: +0jLwzvHPiI= len data: 11 best k: 3
# 8733 => clustering: +0jOYgbvT5Q= len data: 5 best k: 2
# 8735 => clustering: +0k024CEZjE= len data: 2 best k: 1
# 8738 => clustering: +0k8YLH7Bzk= len data: 3 best k: 1
# 8750 => clustering: +0kCb+81xCo= len data: 12 best k: 6
# 8754 => clustering: +0kRq6DWjMo= len data: 4 best k: 1
# 8770 => clustering: +0lLq1fLLh8= len data: 16 best k: 6
# 8784 => clustering: +0ldOFnWHKI= len data: 14 best k: 4
# 8816 => clustering: +0m219fy9mg= len data: 32 best k: 13
# 8829 => clustering: +0m8cD5LNxI= len data: 13 best k: 4
# 8830 => clustering: +0mf1WH9VPU= len data: 1 best k: 1
# 8835 => clustering: +0mrbR16m04= len data: 5 best k: 2
# 8849 => clustering: +0n+CZpEJhA= len data: 14 best k: 2
# 8850 => clustering: +0n/kc2Ln6Y= len data: 1 best k: 1
# 8851 => clustering: +0nSLfaRT4U= len data: 1 best k: 1
# 8853 => clustering: +0nWfnqKc5E= len data: 2 best k: 1
# 8855 => clustering: +0naOrgMaNE= len data: 2 best k: 1
# 8864 => clustering: +0noMU+DYvQ= len data: 9 best k: 3
# 8866 => clustering: +0o+8ddY5hY= len data: 2 best k: 1
# 8872 => clustering: +0oEQA9StP8= len data: 6 best k: 3
# 8884 => clustering: +0oI9gLPsEo= len data: 12 best k: 4
# 8926 => clustering: +0olnxWBe1o= len data: 42 best k: 6
# 8928 => clustering: +0opJwTM1xU= len data: 2 best k: 1
# 8930 => clustering: +0pBEswsNiM= len data: 2 best k: 1
# 8938 => clustering: +0pLa0PuhpM= len data: 8 best k: 1
# 8946 => clustering: +0pxoOrZ2tk= len data: 8 best k: 2
# 8960 => clustering: +0q/YTI3a1U= len data: 14 best k: 4
# 8993 => clustering: +0qB0gEAito= len data: 33 best k: 6
# 8998 => clustering: +0qUC2Lf/no= len data: 5 best k: 2
# 8999 => clustering: +0qYWsJG8Pc= len data: 1 best k: 1
# 9003 => clustering: +0qncVytOs8= len data: 4 best k: 1
# 9006 => clustering: +0qqzEhVqYU= len data: 3 best k: 1
# 9017 => clustering: +0qvuhkDx/s= len data: 11 best k: 2
# 9028 => clustering: +0r1KnE3jLQ= len data: 11 best k: 3
# 9030 => clustering: +0rJ5dWdbjk= len data: 2 best k: 1
# 9034 => clustering: +0sLvp8Fmo8= len data: 4 best k: 1
# 9046 => clustering: +0t68aoRZ9Y= len data: 12 best k: 4
# 9058 => clustering: +0tDZ0ud7Vk= len data: 12 best k: 4
# 9065 => clustering: +0tF7TmUgm8= len data: 7 best k: 3
# 9115 => clustering: +0tLk2uwU1M= len data: 50 best k: 16
# 9117 => clustering: +0tWdErLrjw= len data: 2 best k: 1
# 9120 => clustering: +0tdrH9i7vk= len data: 3 best k: 1
# 9123 => clustering: +0toDUGV56I= len data: 3 best k: 1
# 9138 => clustering: +0uLvWNH8ic= len data: 15 best k: 7
# 9145 => clustering: +0uRYf1Pwxg= len data: 7 best k: 3
# 9146 => clustering: +0uSDNu1jzE= len data: 1 best k: 1
# 9185 => clustering: +0ugFUoLcZw= len data: 39 best k: 9
# 9193 => clustering: +0uro7DlNjQ= len data: 8 best k: 5
# 9208 => clustering: +0vMG+809FA= len data: 15 best k: 2
# 9212 => clustering: +0vbSCkk14g= len data: 4 best k: 1
# 9215 => clustering: +0w8B5Y0vhs= len data: 3 best k: 1
# 9219 => clustering: +0wZhwzyzJo= len data: 4 best k: 1
# 9223 => clustering: +0wchRcQh7M= len data: 4 best k: 1
# 9228 => clustering: +0wm/MNfINw= len data: 5 best k: 3
# 9229 => clustering: +0woT8IrwrI= len data: 1 best k: 1
# 9231 => clustering: +0wtJISaUFw= len data: 2 best k: 1
# 9233 => clustering: +0x7GSFcZZA= len data: 2 best k: 1
# 9244 => clustering: +0xAkgU9AVI= len data: 11 best k: 3
# 9290 => clustering: +0xKwvsIkFA= len data: 46 best k: 9
# 9333 => clustering: +0xdMz9imp0= len data: 43 best k: 6
# 9336 => clustering: +0xkhdzKeF8= len data: 3 best k: 1
# 9357 => clustering: +0xr3WGLoS4= len data: 21 best k: 5
# 9358 => clustering: +0yK6PhPIjg= len data: 1 best k: 1
# 9359 => clustering: +0yLs21FMQw= len data: 1 best k: 1
# 9368 => clustering: +0yTOXnCLJI= len data: 9 best k: 5
# 9375 => clustering: +0yizcpJ2fY= len data: 7 best k: 3
# 9385 => clustering: +0yxoVAU5ww= len data: 10 best k: 4
# 9391 => clustering: +0zR4H4BJtA= len data: 6 best k: 3
# 9398 => clustering: +0zRdwVpJz4= len data: 7 best k: 3
# 9417 => clustering: +1+HVj0E+XU= len data: 19 best k: 5
# 9418 => clustering: +1+e4UeylUo= len data: 1 best k: 1
# 9458 => clustering: +1/47lievSU= len data: 40 best k: 8
# 9459 => clustering: +1/4vHxOHEY= len data: 1 best k: 1
# 9460 => clustering: +1/6ApHy1RE= len data: 1 best k: 1
# 9465 => clustering: +1/6wTR98dc= len data: 5 best k: 4
# 9483 => clustering: +1/BIjrjFJg= len data: 18 best k: 6
# 9506 => clustering: +1/IoqJunRs= len data: 23 best k: 7
# 9507 => clustering: +1/nvllj2qU= len data: 1 best k: 1
# 9514 => clustering: +101jrT4g0s= len data: 7 best k: 2
# 9518 => clustering: +109HCpWehM= len data: 4 best k: 1
# 9519 => clustering: +10I26Q8A8c= len data: 1 best k: 1
# 9521 => clustering: +10ha1hBGvo= len data: 2 best k: 1
# 9545 => clustering: +10mR7Nsqfk= len data: 24 best k: 9
# 9551 => clustering: +11C2XS2F9g= len data: 6 best k: 4
# 9566 => clustering: +11OF0lXTKo= len data: 15 best k: 6
# 9617 => clustering: +11YWdzRJEg= len data: 51 best k: 11
# 9618 => clustering: +11ZvBoYvlU= len data: 1 best k: 1
# 9669 => clustering: +11iMzZJP80= len data: 51 best k: 6
# 9672 => clustering: +11pYCpEZqI= len data: 3 best k: 1
# 9683 => clustering: +1232tTL3qA= len data: 11 best k: 1
# 9684 => clustering: +125oeNzGKY= len data: 1 best k: 1
# 9702 => clustering: +12k/EdJArQ= len data: 18 best k: 8
# 9704 => clustering: +12oVP3bPCU= len data: 2 best k: 1
# 9741 => clustering: +13/Y57RH00= len data: 37 best k: 3
# 9764 => clustering: +13OKEqwybA= len data: 23 best k: 10
# 9765 => clustering: +13iOpIT0A8= len data: 1 best k: 1
# 9766 => clustering: +13sStiLRfc= len data: 1 best k: 1
# 9767 => clustering: +14+G7y34oM= len data: 1 best k: 1
# 9769 => clustering: +144gghjKy8= len data: 2 best k: 1
# 9785 => clustering: +146m1YJnNY= len data: 16 best k: 3
# 9795 => clustering: +148nEcjzq4= len data: 10 best k: 3
# 9800 => clustering: +14Xb4cGZTg= len data: 5 best k: 4
# 9802 => clustering: +14XeW0rSJc= len data: 2 best k: 1
# 9819 => clustering: +15DcfhtI0k= len data: 17 best k: 4
# 9838 => clustering: +15MZjEFNN4= len data: 19 best k: 6
# 9878 => clustering: +15spL7OWvQ= len data: 40 best k: 7
# 9927 => clustering: +16/PRicyeM= len data: 49 best k: 7
# 9938 => clustering: +1648JwPXUE= len data: 11 best k: 3
# 9977 => clustering: +1670k6aThA= len data: 39 best k: 7
# 10027 => clustering: +167om9TIV4= len data: 50 best k: 5
# 10030 => clustering: +16KJXYLYTA= len data: 3 best k: 1
# 10037 => clustering: +16MfJAhvas= len data: 7 best k: 3
# 10040 => clustering: +16uqeQO7lM= len data: 3 best k: 1
# 10063 => clustering: +177L0kkqH8= len data: 23 best k: 6
# 10067 => clustering: +17GbLEOVXQ= len data: 4 best k: 1
# 10072 => clustering: +17gz0syXTg= len data: 5 best k: 3
# 10073 => clustering: +17oKhlOd7Y= len data: 1 best k: 1
# 10083 => clustering: +18//lB6Ybk= len data: 10 best k: 6
# 10087 => clustering: +182ID1sv5I= len data: 4 best k: 1
# 10141 => clustering: +186yOvxXac= len data: 54 best k: 7
# 10142 => clustering: +18APJbQbiA= len data: 1 best k: 1
# 10192 => clustering: +18DYvKBe/4= len data: 50 best k: 6
# 10197 => clustering: +18bl1lTfSg= len data: 5 best k: 2
# 10210 => clustering: +197PyCOQ4I= len data: 13 best k: 4
# 10213 => clustering: +19Kf3x6+nY= len data: 3 best k: 1
# 10220 => clustering: +19azUWEc5A= len data: 7 best k: 4
# 10227 => clustering: +19b5bgGBMQ= len data: 7 best k: 2
# ...
# 38175 => clustering: +9hOuR9uXc4= len data: 4 best k: 1
# 38192 => clustering: +9hS2byThO8= len data: 17 best k: 5
# 38204 => clustering: +9hnlLEcwjA= len data: 12 best k: 2
# 38205 => clustering: +9iEfgcyLLk= len data: 1 best k: 1
# 38217 => clustering: +9iNUq8Cg3Q= len data: 12 best k: 5
# 38219 => clustering: +9iS3wDuKOU= len data: 2 best k: 1
# 38220 => clustering: +9j0fZHccHk= len data: 1 best k: 1
# 38235 => clustering: +9jIsmAtK2g= len data: 15 best k: 4
# 38236 => clustering: +9jrQs7pXAU= len data: 1 best k: 1
# 38242 => clustering: +9k8MPiFwDA= len data: 6 best k: 3
# 38250 => clustering: +9kUULg86Nw= len data: 8 best k: 4
# 38260 => clustering: +9kWfbUaRxk= len data: 10 best k: 3
# 38261 => clustering: +9koZEOD0yE= len data: 1 best k: 1
# 38290 => clustering: +9kqKEiTl8A= len data: 29 best k: 7
# 38301 => clustering: +9kxRg64fy8= len data: 11 best k: 5
# 38305 => clustering: +9kys4E6P8w= len data: 4 best k: 1
# 38311 => clustering: +9l4QiY1ZSI= len data: 6 best k: 5
# 38315 => clustering: +9l6chkexn4= len data: 4 best k: 1
# 38337 => clustering: +9lAPed2BRg= len data: 22 best k: 4
# 38340 => clustering: +9lPiVbvLm8= len data: 3 best k: 1
# 38359 => clustering: +9m+41+eS+Y= len data: 19 best k: 6
# 38366 => clustering: +9m/2xvYS/A= len data: 7 best k: 4
# 38370 => clustering: +9m1B52J2LQ= len data: 4 best k: 1
# 38375 => clustering: +9mkdMGTM5U= len data: 5 best k: 3
# 38383 => clustering: +9mtVAmrzNk= len data: 8 best k: 2
# 38433 => clustering: +9nVCYzQnwc= len data: 50 best k: 7
# 38455 => clustering: +9nssT4Qp2U= len data: 22 best k: 4
# 38468 => clustering: +9o6mP/qbBs= len data: 13 best k: 4
# 38472 => clustering: +9oMsbK7yV8= len data: 4 best k: 1
# 38502 => clustering: +9oQathZWtA= len data: 30 best k: 8
# 38503 => clustering: +9oTH+LWqQU= len data: 1 best k: 1
# 38546 => clustering: +9p4qMreOoI= len data: 43 best k: 5
# 38570 => clustering: +9pbhaL7cEo= len data: 24 best k: 6
# 38575 => clustering: +9q75LehfKc= len data: 5 best k: 3
# 38609 => clustering: +9qv0fkqYgU= len data: 34 best k: 6
# 38653 => clustering: +9rhEHUtKpg= len data: 44 best k: 5
# 38654 => clustering: +9sFcphNS7w= len data: 1 best k: 1
# 38656 => clustering: +9sIXPZVGu0= len data: 2 best k: 1
# 38661 => clustering: +9sQBw5+Ri4= len data: 5 best k: 3
# 38663 => clustering: +9sbnWebdO0= len data: 2 best k: 1
# 38679 => clustering: +9skoi5qs78= len data: 16 best k: 4
# 38680 => clustering: +9st9bQrsJk= len data: 1 best k: 1
# 38708 => clustering: +9syP8mKxBg= len data: 28 best k: 10
# 38717 => clustering: +9tIssbwrCk= len data: 9 best k: 4
# 38726 => clustering: +9tLYHTn2+k= len data: 9 best k: 2
# 38750 => clustering: +9tbT3X+IYM= len data: 24 best k: 8
# 38753 => clustering: +9txGGnpDM4= len data: 3 best k: 1
# 38756 => clustering: +9uH83jm9Nc= len data: 3 best k: 1
# 38760 => clustering: +9uVoVSXboo= len data: 4 best k: 1
# 38769 => clustering: +9uYaVN7xMI= len data: 9 best k: 4
# 38788 => clustering: +9ubTKtuRAI= len data: 19 best k: 5
# 38811 => clustering: +9ucGJpOIns= len data: 23 best k: 5
# 38837 => clustering: +9v+ZIlrySU= len data: 26 best k: 8
# 38840 => clustering: +9vKFV4mn7I= len data: 3 best k: 1
# 38843 => clustering: +9vm1jpa07k= len data: 3 best k: 1
# 38847 => clustering: +9vt533QP9g= len data: 4 best k: 1
# 38869 => clustering: +9vw3JX+nQ4= len data: 22 best k: 8
# 38875 => clustering: +9w2USZTHaA= len data: 6 best k: 5
# 38876 => clustering: +9w5M4bZLKg= len data: 1 best k: 1
# 38877 => clustering: +9w8opVm5uU= len data: 1 best k: 1
# 38884 => clustering: +9w9/MbrDnU= len data: 7 best k: 3
# 38886 => clustering: +9wE4l9wGYA= len data: 2 best k: 1
# 38888 => clustering: +9wLBNIEdus= len data: 2 best k: 1
# 38914 => clustering: +9wNyZkq684= len data: 26 best k: 7
# 38930 => clustering: +9wQGw0IuN4= len data: 16 best k: 4
# 38936 => clustering: +9wRdSjKa/w= len data: 6 best k: 3
# 38945 => clustering: +9wbRV+CCMY= len data: 9 best k: 2
# 38957 => clustering: +9wdJqp1c7E= len data: 12 best k: 4
# 39000 => clustering: +9we9c0gvEY= len data: 43 best k: 1
# 39012 => clustering: +9wmoDkixDc= len data: 12 best k: 4
# 39013 => clustering: +9wukM7JoTs= len data: 1 best k: 1
# 39015 => clustering: +9x0VtMeR88= len data: 2 best k: 1
# 39035 => clustering: +9x6WLEWIDI= len data: 20 best k: 6
# 39040 => clustering: +9x9oalt4fc= len data: 5 best k: 3
# 39045 => clustering: +9xUl9f9FcM= len data: 5 best k: 2
# 39047 => clustering: +9xZ1n5uNnY= len data: 2 best k: 1
# 39086 => clustering: +9xptUoKYqE= len data: 39 best k: 7
# 39087 => clustering: +9xqxRYn+hM= len data: 1 best k: 1
# 39117 => clustering: +9yJoBsAES4= len data: 30 best k: 6
# 39118 => clustering: +9yTBVpeibY= len data: 1 best k: 1
# 39119 => clustering: +9z6SpYAOoo= len data: 1 best k: 1
# 39131 => clustering: +9zEyd45KMc= len data: 12 best k: 5
# 39132 => clustering: +9zI/m/hvVY= len data: 1 best k: 1
# 39171 => clustering: +9zM3Smnd+0= len data: 39 best k: 6
# 39195 => clustering: +9zWvGt/SgM= len data: 24 best k: 6
# 39209 => clustering: +9zkYu2Y5i8= len data: 14 best k: 2
# 39241 => clustering: +A+1O8b2RcM= len data: 32 best k: 9
# 39265 => clustering: +A+IE+5O4Iw= len data: 24 best k: 7
# 39266 => clustering: +A+QdNh69g4= len data: 1 best k: 1
# 39272 => clustering: +A+cpyMqLdE= len data: 6 best k: 2
# 39274 => clustering: +A+klJn19rg= len data: 2 best k: 1
# 39286 => clustering: +A0191iuhaU= len data: 12 best k: 5
# 39298 => clustering: +A0Ncpc/n20= len data: 12 best k: 2
# 39313 => clustering: +A0b/AS3wl8= len data: 15 best k: 3
# 39338 => clustering: +A0zWFEVbSA= len data: 25 best k: 6
# 39339 => clustering: +A1/5WQ+COM= len data: 1 best k: 1
# 39341 => clustering: +A1FsHni32s= len data: 2 best k: 1
# 39343 => clustering: +A1Zzw79YZc= len data: 2 best k: 1
# 39344 => clustering: +A1gV0htwaA= len data: 1 best k: 1
# 39375 => clustering: +A1lMP/gx/o= len data: 31 best k: 7
# 39393 => clustering: +A1r7EOnPiM= len data: 18 best k: 5
# 39394 => clustering: +A1tIRD+FEQ= len data: 1 best k: 1
# 39402 => clustering: +A28HsoUGc0= len data: 8 best k: 2
# 39415 => clustering: +A2dqHbNG5g= len data: 13 best k: 8
# 39465 => clustering: +A2hnghCeHg= len data: 50 best k: 6
# 39466 => clustering: +A3/BuGr6zM= len data: 1 best k: 1
# 39470 => clustering: +A3Lp8W8aFY= len data: 4 best k: 1
# 39484 => clustering: +A3VSp0mtS4= len data: 14 best k: 5
# 39486 => clustering: +A4YD0egxWg= len data: 2 best k: 1
# 39492 => clustering: +A4YrqWveXc= len data: 6 best k: 3
# 39493 => clustering: +A4fqbBAaIk= len data: 1 best k: 1
# 39497 => clustering: +A4hx6jD988= len data: 4 best k: 1
# 39524 => clustering: +A5PcwpIS/s= len data: 27 best k: 10
# 39538 => clustering: +A5q+QqzcCY= len data: 14 best k: 3
# 39549 => clustering: +A6+ts3Rrqo= len data: 11 best k: 2
# 39551 => clustering: +A6JbGDD7Eg= len data: 2 best k: 1
# 39588 => clustering: +A6M5V8hATw= len data: 37 best k: 10
# 39590 => clustering: +A6hfXX0heU= len data: 2 best k: 1
# 39595 => clustering: +A8ik5WHoiw= len data: 5 best k: 2
# 39635 => clustering: +A8jnXMhYfc= len data: 40 best k: 11
# 39637 => clustering: +A98v8jsunk= len data: 2 best k: 1
# 39641 => clustering: +A9UjHAwglk= len data: 4 best k: 1
# 39649 => clustering: +A9sGK+obdE= len data: 8 best k: 4
# 39651 => clustering: +A9wM9hDE4A= len data: 2 best k: 1
# 39668 => clustering: +A9wzKijQKI= len data: 17 best k: 3
# 39680 => clustering: +AA/A/2SRSA= len data: 12 best k: 3
# 39685 => clustering: +AA0q17+wIM= len data: 5 best k: 2
# 39726 => clustering: +AA6ZhwVrVU= len data: 41 best k: 10
# 39734 => clustering: +AAODo1Q4FE= len data: 8 best k: 5
# 39735 => clustering: +AAlV2tDZkI= len data: 1 best k: 1
# 39749 => clustering: +AAsojmf6Ok= len data: 14 best k: 5
# 39780 => clustering: +AAxEmW6LvE= len data: 31 best k: 5
# 39784 => clustering: +ACJC3mu0Rk= len data: 4 best k: 1
# 39789 => clustering: +ACXKO05Ewc= len data: 5 best k: 2
# 39829 => clustering: +AClWN9vUDo= len data: 40 best k: 7
# 39831 => clustering: +ACq62E4ync= len data: 2 best k: 1
# 39884 => clustering: +AD1HOxmEcY= len data: 53 best k: 5
# 39886 => clustering: +AD4BAmAeV0= len data: 2 best k: 1
# 39902 => clustering: +ADPBAbUZDs= len data: 16 best k: 2
# 39903 => clustering: +ADPvkvUv5E= len data: 1 best k: 1
# 39912 => clustering: +ADdE/BlPCw= len data: 9 best k: 4
# 39922 => clustering: +AEdX9UaIOI= len data: 10 best k: 4
# 39923 => clustering: +AFEbUli1fQ= len data: 1 best k: 1
# 39924 => clustering: +AFGkoYpsG0= len data: 1 best k: 1
# 39925 => clustering: +AFKxs6zyi8= len data: 1 best k: 1
# 39926 => clustering: +AFRrsi/ZbM= len data: 1 best k: 1
# 39927 => clustering: +AFfHCxHvtg= len data: 1 best k: 1
# 39937 => clustering: +AFpB7z5ln8= len data: 10 best k: 5
# 39948 => clustering: +AGG5I60KwY= len data: 11 best k: 4
# 39950 => clustering: +AGco++WIfQ= len data: 2 best k: 1
# 39961 => clustering: +AGn/6boJYs= len data: 11 best k: 4
# 40006 => clustering: +AGtTZXILA0= len data: 45 best k: 5
# 40014 => clustering: +AI51XwCZ3s= len data: 8 best k: 4
# 40021 => clustering: +AIH1SgZR6c= len data: 7 best k: 4
# 40064 => clustering: +AIayUt8wiM= len data: 43 best k: 6
# 40068 => clustering: +AIz5TeTMYU= len data: 4 best k: 1
# 40069 => clustering: +AJH+23oMko= len data: 1 best k: 1
# 40070 => clustering: +AJOzxSn3fU= len data: 1 best k: 1
# 40073 => clustering: +AJTVTFVQ+w= len data: 3 best k: 1
# 40127 => clustering: +AKKf+50qDA= len data: 54 best k: 7
# 40133 => clustering: +AKLq6qaOWU= len data: 6 best k: 3
# 40157 => clustering: +AKMMLBqlHc= len data: 24 best k: 9
# 40162 => clustering: +AKOpiZgyWM= len data: 5 best k: 3
# 40177 => clustering: +AL1Q0Uvn38= len data: 15 best k: 4
# 40179 => clustering: +ALIPuAUO2A= len data: 2 best k: 1
# 40195 => clustering: +ALazXkWeZ4= len data: 16 best k: 1
# 40225 => clustering: +AM+ZLKMnEU= len data: 30 best k: 5
# 40226 => clustering: +AMTUAyHtVE= len data: 1 best k: 1
# 40227 => clustering: +AMWO9KHi+k= len data: 1 best k: 1
# 40228 => clustering: +AMh9/VDf1Y= len data: 1 best k: 1
# 40230 => clustering: +AMi/Yc6/cQ= len data: 2 best k: 1
# 40231 => clustering: +AMjOHuR4/Y= len data: 1 best k: 1
# 40238 => clustering: +AMxz+Aysno= len data: 7 best k: 4
# 40255 => clustering: +ANObOtZPUc= len data: 17 best k: 5
# 40262 => clustering: +ANbk+DM2cI= len data: 7 best k: 2
# 40271 => clustering: +ANxeTxRlgM= len data: 9 best k: 3
# 40292 => clustering: +AO1oENOfaI= len data: 21 best k: 6
# 40293 => clustering: +AO26vg4PVM= len data: 1 best k: 1
# 40313 => clustering: +AO5Vw5vcto= len data: 20 best k: 4
# 40316 => clustering: +AP8tVgXYlg= len data: 3 best k: 1
# 40319 => clustering: +APEIuBN7/E= len data: 3 best k: 1
# 40320 => clustering: +APELsq6QXo= len data: 1 best k: 1
# 40358 => clustering: +APNWudXR8g= len data: 38 best k: 9
# 40393 => clustering: +APsoauzUyU= len data: 35 best k: 5
# 40398 => clustering: +AQJiBgjLWA= len data: 5 best k: 3
# 40403 => clustering: +AQL4k5w/6Y= len data: 5 best k: 3
# 40450 => clustering: +AQLlxByvcA= len data: 47 best k: 8
# 40487 => clustering: +AQLs/sj2CM= len data: 37 best k: 9
# 40513 => clustering: +AQq4i6C/ZE= len data: 26 best k: 5
# 40523 => clustering: +AQvnNTa9Oo= len data: 10 best k: 5
# 40538 => clustering: +AR37F0MF0o= len data: 15 best k: 4
# 40543 => clustering: +ARHMgs3aOs= len data: 5 best k: 3
# 40545 => clustering: +ARJJ0RHv9g= len data: 2 best k: 1
# 40553 => clustering: +ARmrjXLVsg= len data: 8 best k: 3
# 40554 => clustering: +ARx60wc//4= len data: 1 best k: 1
# 40562 => clustering: +AS7Gcl/+20= len data: 8 best k: 3
# 40569 => clustering: +ASX2wTbdA8= len data: 7 best k: 5
# 40570 => clustering: +ASogxY1cxs= len data: 1 best k: 1
# 40583 => clustering: +AStqQ9dMg8= len data: 13 best k: 6
# 40587 => clustering: +AT+DIQh5lk= len data: 4 best k: 1
# 40588 => clustering: +ATBvjvRLjg= len data: 1 best k: 1
# 40590 => clustering: +ATIDrGDb24= len data: 2 best k: 1
# 40630 => clustering: +AUOcJfEVkE= len data: 40 best k: 6
# 40637 => clustering: +AUizWzCh+k= len data: 7 best k: 3
# 40642 => clustering: +AUofLAZBVY= len data: 5 best k: 4
# 40674 => clustering: +AUsSqnJtlY= len data: 32 best k: 12
# 40675 => clustering: +AV1bJY6FoU= len data: 1 best k: 1
# 40681 => clustering: +AVNOaAOqkc= len data: 6 best k: 2
# 40694 => clustering: +AWW5DnbCk0= len data: 13 best k: 4
# 40706 => clustering: +AWh4qrGGGE= len data: 12 best k: 2
# 40712 => clustering: +AWt9joHBFc= len data: 6 best k: 4
# 40732 => clustering: +AWyznQ4gds= len data: 20 best k: 5
# 40742 => clustering: +AXno0mrCM8= len data: 10 best k: 5
# 40755 => clustering: +AYW1W8XDqE= len data: 13 best k: 7
# 40760 => clustering: +AYd27NJFos= len data: 5 best k: 3
# 40766 => clustering: +AYhtNCBSNs= len data: 6 best k: 4
# 40788 => clustering: +AYild/IEKA= len data: 22 best k: 5
# 40812 => clustering: +AYoUkd9duI= len data: 24 best k: 4
# 40859 => clustering: +AYqDRwBPpY= len data: 47 best k: 7
# 40860 => clustering: +AZ+1XmsMSw= len data: 1 best k: 1
# 40864 => clustering: +AZ5EU5HWHM= len data: 4 best k: 1
# 40868 => clustering: +AZ7bQllQDM= len data: 4 best k: 1
# 40875 => clustering: +AZKmgO9ylA= len data: 7 best k: 3
# 40876 => clustering: +AZPsblwPUw= len data: 1 best k: 1
# 40886 => clustering: +AaRFU4Sn8U= len data: 10 best k: 3
# 40892 => clustering: +AazhXsAS+I= len data: 6 best k: 3
# 40935 => clustering: +AbNhNToXmQ= len data: 43 best k: 8
# 40945 => clustering: +Ac+JXjJcDM= len data: 10 best k: 5
# 40949 => clustering: +AcFqL6PIrs= len data: 4 best k: 1
# 40950 => clustering: +AcTzHiEgyo= len data: 1 best k: 1
# 40974 => clustering: +AcaGSnu58k= len data: 24 best k: 6
# 40981 => clustering: +AcdaY+eKlI= len data: 7 best k: 4
# 40992 => clustering: +AdDtriiYy4= len data: 11 best k: 4
# 41020 => clustering: +AdF3fNvm/w= len data: 28 best k: 8
# 41024 => clustering: +AdSdhubgd8= len data: 4 best k: 1
# 41051 => clustering: +AdnsFrSDis= len data: 27 best k: 6
# 41052 => clustering: +AdvHW8NFLY= len data: 1 best k: 1
# 41055 => clustering: +AeHK3zxyjk= len data: 3 best k: 1
# 41095 => clustering: +Aea0rgbFfM= len data: 40 best k: 7
# 41096 => clustering: +AejtS7vVTI= len data: 1 best k: 1
# 41101 => clustering: +AeoK2pyYww= len data: 5 best k: 3
# 41102 => clustering: +Af8veSfjP0= len data: 1 best k: 1
# 41134 => clustering: +Afe7DKIf4Y= len data: 32 best k: 11
# 41143 => clustering: +AfeMZbJ7dY= len data: 9 best k: 3
# 41167 => clustering: +Afr71lJaNE= len data: 24 best k: 4
# 41168 => clustering: +Afsh6jR6eY= len data: 1 best k: 1
# 41181 => clustering: +AfsvMkAFRA= len data: 13 best k: 3
# 41188 => clustering: +Aga7XPsRPI= len data: 7 best k: 3
# 41240 => clustering: +AgbaBEy0ug= len data: 52 best k: 8
# 41247 => clustering: +Agef6ScLbU= len data: 7 best k: 4
# 41279 => clustering: +Aggfq9Nwt8= len data: 32 best k: 8
# 41288 => clustering: +Ags1UEUBwg= len data: 9 best k: 3
# 41293 => clustering: +Ah6XCuXhG8= len data: 5 best k: 2
# 41333 => clustering: +Ahl10R0h9c= len data: 40 best k: 8
# 41349 => clustering: +AhqT1qEIVo= len data: 16 best k: 4
# 41353 => clustering: +Ai3fdqja28= len data: 4 best k: 1
# 41381 => clustering: +Ai6bUnvS8o= len data: 28 best k: 10
# 41384 => clustering: +AiQ7xiYkQ4= len data: 3 best k: 1
# 41385 => clustering: +AiUuWBXNYo= len data: 1 best k: 1
# 41397 => clustering: +Aj9eYP560s= len data: 12 best k: 5
# 41398 => clustering: +AjN6dCQNAU= len data: 1 best k: 1
# 41399 => clustering: +AjfrREhToo= len data: 1 best k: 1
# 41427 => clustering: +AjoH5qjJpo= len data: 28 best k: 9
# 41428 => clustering: +Ajqp1BR8H0= len data: 1 best k: 1
# 41429 => clustering: +AjxuuHGYes= len data: 1 best k: 1
# 41463 => clustering: +Ajz+SdANqk= len data: 34 best k: 7
# 41466 => clustering: +AkGZboxeow= len data: 3 best k: 1
# 41467 => clustering: +AkI9gsVev4= len data: 1 best k: 1
# 41517 => clustering: +Al/+kZNli8= len data: 50 best k: 7
# 41523 => clustering: +Al3SacISnw= len data: 6 best k: 4
# 41528 => clustering: +AlSAw/zRKk= len data: 5 best k: 3
# 41536 => clustering: +Alm5fjpdnU= len data: 8 best k: 4
# 41562 => clustering: +Altk91TLJ0= len data: 26 best k: 3
# 41583 => clustering: +Am+G79sOM8= len data: 21 best k: 5
# 41585 => clustering: +AmUm7/8Kig= len data: 2 best k: 1
# 41600 => clustering: +AmV0h+IyOs= len data: 15 best k: 4
# 41616 => clustering: +AmZ18bQvTQ= len data: 16 best k: 4
# 41652 => clustering: +Amgwo9J42E= len data: 36 best k: 11
# 41659 => clustering: +AmpFK6E/E4= len data: 7 best k: 3
# 41660 => clustering: +An1wGFtLS4= len data: 1 best k: 1
# 41677 => clustering: +An2ZIjv8s8= len data: 17 best k: 3
# 41680 => clustering: +An4ETDU/uo= len data: 3 best k: 1
# 41705 => clustering: +An5FNf+zfw= len data: 25 best k: 7
# final
# 3529
